# %% [markdown]
# #Analysis on Skyrim Data

# %%
f = read.csv("skyrim.csv");

vars = cbind( f$likes, f$downloads, f$time, f$unique_dl, f$views, f$dl_dif);

dimnames(vars)[[2]] <- c("likes", "downloads", "time", "unique_dl", "views");

data <- data.frame(vars);
length(vars)
# Out:
# [1] 198700

# %%
dim(vars)
# Out:
# [1] 39740     5

# %%
summary(data);
# Out:
#      likes            downloads             time          unique_dl
#  Min.   :     0.0   Min.   :       0   Min.   :  90.0   Min.   :      0
#  1st Qu.:    15.0   1st Qu.:     350   1st Qu.: 603.0   1st Qu.:    253
#  Median :    48.0   Median :    1078   Median :1023.0   Median :    763
#  Mean   :   602.4   Mean   :   17552   Mean   : 936.5   Mean   :  11106
#  3rd Qu.:   178.0   3rd Qu.:    4152   3rd Qu.:1308.0   3rd Qu.:   2906
#  Max.   :351178.0   Max.   :17112581   Max.   :1473.0   Max.   :8224648
#      views             dl_diff
#  Min.   :     308   Min.   :      0
#  1st Qu.:    8481   1st Qu.:     87
#  Median :   17067   Median :    298
#  Mean   :   68414   Mean   :   6446
#  3rd Qu.:   39919   3rd Qu.:   1204
#  Max.   :24564770   Max.   :8887933

# %%
cor(vars, use="pairwise.complete.obs", method="spearman");
# Out:
#               likes downloads      time unique_dl     views   dl_diff
# likes     1.0000000 0.9425676 0.1054362 0.9520167 0.8091535 0.8992733
# downloads 0.9425676 1.0000000 0.2978757 0.9972980 0.8886313 0.9839613
# time      0.1054362 0.2978757 1.0000000 0.2653177 0.3854834 0.3757441
# unique_dl 0.9520167 0.9972980 0.2653177 1.0000000 0.8878730 0.9688647
# views     0.8091535 0.8886313 0.3854834 0.8878730 1.0000000 0.8729717
# dl_diff   0.8992733 0.9839613 0.3757441 0.9688647 0.8729717 1.0000000

# %%
res<-prcomp(vars, retx=F,scale=T, na.action = na.omit)$rotation[,1:3];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:3)
  print(t(res[resAbs[,i]>.3,i,drop=FALSE]));
# Out:
#         likes downloads unique_dl    views   dl_diff
# PC1 0.4322002 0.4561355 0.4566535 0.446074 0.4429343
#          time
# PC2 0.9988697
#          likes downloads   dl_diff
# PC3 -0.6981518 0.3109289 0.5628126

# %%
plot(1:6,cumsum(prcomp(vars, retx=F,scale=T)$sdev^2)/sum(prcomp(vars, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title

# %% [markdown]
# #Analysis of Oblivion Data

# %%
f = read.csv("../scripts/oblivion.csv");

vars = cbind( f$likes, f$downloads, f$time, f$unique_dl, f$views, f$dl_dif);

dimnames(vars)[[2]] <- c("likes", "downloads", "time", "unique_dl", "views", "dl_diff");

data <- data.frame(vars);

# %%
summary(data);
# Out:
#      likes            downloads              time        unique_dl
#  Min.   :    0.00   Min.   :      0.0   Min.   :  90   Min.   :     0.0
#  1st Qu.:    5.00   1st Qu.:    179.2   1st Qu.:1831   1st Qu.:   141.0
#  Median :   15.00   Median :    518.0   Median :2429   Median :   403.5
#  Mean   :   79.13   Mean   :   4549.0   Mean   :2376   Mean   :  2937.6
#  3rd Qu.:   47.00   3rd Qu.:   1716.5   3rd Qu.:3083   3rd Qu.:  1304.0
#  Max.   :27545.00   Max.   :1742557.0   Max.   :3855   Max.   :964238.0
#      views            dl_diff
#  Min.   :    113   Min.   :     0
#  1st Qu.:   4526   1st Qu.:    37
#  Median :   8562   Median :   113
#  Mean   :  23090   Mean   :  1611
#  3rd Qu.:  18703   3rd Qu.:   405
#  Max.   :4392937   Max.   :865681

# %%
cor(vars,method="spearman");
# Out:
#                likes downloads       time unique_dl     views   dl_diff
# likes     1.00000000 0.8970096 0.05784778 0.8971988 0.7840097 0.8833806
# downloads 0.89700961 1.0000000 0.14825992 0.9986865 0.8769403 0.9882837
# time      0.05784778 0.1482599 1.00000000 0.1509854 0.1789497 0.1381862
# unique_dl 0.89719879 0.9986865 0.15098544 1.0000000 0.8774275 0.9795430
# views     0.78400968 0.8769403 0.17894972 0.8774275 1.0000000 0.8633024
# dl_diff   0.88338065 0.9882837 0.13818620 0.9795430 0.8633024 1.0000000

# %%
res<-prcomp(vars, retx=F,scale=T)$rotation[,1:3];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:3)
  print(t(res[resAbs[,i]>.3,i,drop=FALSE]));
# Out:
#         likes downloads unique_dl     views dl_diff
# PC1 0.4325221 0.4638962 0.4646073 0.4425962 0.42916
#           time
# PC2 -0.9981531
#          likes downloads      views  dl_diff
# PC3 -0.5380437 0.3015934 -0.4416876 0.650804

# %%
plot(1:6,cumsum(prcomp(vars, retx=F,scale=T)$sdev^2)/sum(prcomp(vars, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title

# %% [markdown]
# #Analysis of Morrowind Data

# %%
f = read.csv("../scripts/morrowind.csv");

vars = cbind( f$likes, f$downloads, f$time, f$unique_dl, f$views,f$dl_dif);

dimnames(vars)[[2]] <- c("likes", "downloads", "time", "unique_dl", "views","dl_diff");

data <- data.frame(vars);

# %%
summary(data);
# Out:
#      likes            downloads             time          unique_dl
#  Min.   :    0.00   Min.   :     0.0   Min.   :  90.0   Min.   :     0.0
#  1st Qu.:    5.00   1st Qu.:   121.0   1st Qu.: 797.5   1st Qu.:    99.0
#  Median :   13.00   Median :   289.5   Median :1902.5   Median :   231.5
#  Mean   :   74.33   Mean   :  1788.3   Mean   :1894.4   Mean   :  1386.9
#  3rd Qu.:   42.00   3rd Qu.:   851.8   3rd Qu.:3027.2   3rd Qu.:   677.8
#  Max.   :10179.00   Max.   :268100.0   Max.   :4365.0   Max.   :199165.0
#      views            dl_diff
#  Min.   :    417   Min.   :    0.0
#  1st Qu.:   2812   1st Qu.:   20.0
#  Median :   4858   Median :   49.0
#  Mean   :  11525   Mean   :  401.4
#  3rd Qu.:   9199   3rd Qu.:  159.8
#  Max.   :1212512   Max.   :68935.0

# %%
cor(vars,method="spearman");
# Out:
#                 likes downloads        time unique_dl     views    dl_diff
# likes      1.00000000 0.9049472 -0.06246698 0.9053991 0.7747604 0.87378804
# downloads  0.90494724 1.0000000  0.14416631 0.9954684 0.8684775 0.95016658
# time      -0.06246698 0.1441663  1.00000000 0.1689473 0.2717363 0.00987345
# unique_dl  0.90539910 0.9954684  0.16894735 1.0000000 0.8810804 0.92018515
# views      0.77476044 0.8684775  0.27173632 0.8810804 1.0000000 0.77871206
# dl_diff    0.87378804 0.9501666  0.00987345 0.9201851 0.7787121 1.00000000

# %%
res<-prcomp(vars, retx=F,scale=T)$rotation[,1:2];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:2)
  print(t(res[resAbs[,i]>.3,i,drop=FALSE]));
# Out:
#         likes downloads unique_dl    views   dl_diff
# PC1 0.4394767 0.4531766 0.4500279 0.444561 0.4482894
#          time
# PC2 0.9988506

# %%
plot(1:6,cumsum(prcomp(vars, retx=F,scale=T)$sdev^2)/sum(prcomp(vars, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title
