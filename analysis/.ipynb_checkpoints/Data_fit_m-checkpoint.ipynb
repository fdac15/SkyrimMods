# %%
data = read.csv("fit_data_m.csv")

# %%
data = data[,colSums(data) >0 ]

# %%
dim(data)
# Out:
# [1] 2397  101

# %%
summary(data)
# Out:
#       Mod             Udl              time           Pop1
#  Min.   :  937   Min.   :     0   Min.   : 178   Min.   :0.00000
#  1st Qu.:23012   1st Qu.:   108   1st Qu.:1017   1st Qu.:0.00000
#  Median :37803   Median :   269   Median :1831   Median :0.00000
#  Mean   :31690   Mean   :  1578   Mean   :1858   Mean   :0.01001
#  3rd Qu.:42568   3rd Qu.:   832   3rd Qu.:2583   3rd Qu.:0.00000
#  Max.   :43873   Max.   :185504   Max.   :3988   Max.   :1.00000
#      Pop10           Chargen         CompanionFriendly   Companions
#  Min.   :0.0000   Min.   :0.000000   Min.   :0.00000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.0000
#  Median :0.0000   Median :0.000000   Median :0.00000   Median :0.0000
#  Mean   :0.1001   Mean   :0.005423   Mean   :0.04673   Mean   :0.0292
#  3rd Qu.:0.0000   3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.0000
#  Max.   :1.0000   Max.   :1.000000   Max.   :1.00000   Max.   :1.0000
# ...

# %%
# Define a function
hiCor <- function(x, level){
  res <- cor(x,method="spearman");
  res1 <- res; res1[res<0] <- -res[res < 0];
  for (i in 1:dim(x)[2]){
    res1[i,i] <- 0;
  }
  sel <- apply(res1,1,max) > level;
  res[sel,sel];
}
hiCor(data,.7)
# Out:
#                             Mod        time Environment_Sky Environment_Weather
# Mod                  1.00000000 -0.99933278     -0.04054205          -0.0156312
# time                -0.99933278  1.00000000      0.04059352           0.0157206
# Environment_Sky     -0.04054205  0.04059352      1.00000000           0.7060705
# Environment_Weather -0.01563120  0.01572060      0.70607051           1.0000000

# %%
plot(1:101,cumsum(prcomp(data, retx=F,scale=T)$sdev^2)/sum(prcomp(data, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title

# %%
res<-prcomp(data, retx=F,scale=T)$rotation[,1:3];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:3)
  print(t(res[resAbs[,i]>.1,i,drop=FALSE]));
# Out:
#     CompanionFriendly Forfemalecharacters Formalecharacters
# PC1         0.1662891           0.1132778         0.1188002
#     GameplayEffectsChanges Fairandbalanced Environment_Other Newmodels
# PC1              0.1429413       0.1968281         0.1137648 0.1344929
#     Newtextures ScriptedEvents Lore_Friendly     Czech   English    French
# PC1   0.1580197       0.125802     0.2074662 0.1431594 0.2328845 0.1445548
#        German   Italian  Japanese Otherlanguages    Polish   Russian   Spanish
# PC1 0.1633492 0.1370184 0.1486623      0.1321919 0.1647229 0.1678077 0.1194507
#         Books  Clothing Clothing_Male Locations_Buildings Locations_WorldMap
# PC1 0.1256441 0.1125683     0.1198523           0.1062124           0.106538
#     Magic_Enchantments Magic_Potions Magic_Spells NPCVendors      NPCs
# PC1          0.1276568      0.126096    0.1522752   0.118911 0.1529671
#       Weapons       none
# PC1 0.1328362 -0.2538447
# ...

# %%
colnames(data)
# Out:
#   [1] "Mod"                         "Udl"
#   [3] "time"                        "Pop1"
#   [5] "Pop10"                       "Chargen"
#   [7] "CompanionFriendly"           "Companions"
#   [9] "Compilation"                 "Forfemalecharacters"
#  [11] "Formalecharacters"           "GameplayEffectsChanges"
#  [13] "Official"                    "PerformanceOptimization"
#  [15] "Poses"                       "Relatedtohorses"
#  [17] "RelatedtoMoviesTVOtherGames" "Relatedtovampires"
#  [19] "Replacer"                    "Solstheim"
#  [21] "Cheating"                    "Fairandbalanced"
#  [23] "Unbalanced"                  "Animation_Modified"
#  [25] "Animation_New"               "Audio_Music"
#  [27] "Audio_SoundFX"               "Audio_Voices"
#  [29] "Birthsigns"                  "Bodymodels"
#  [31] "Classescomponent"            "Environment_Other"
#  [33] "Environment_Sky"             "Environment_Water"
#  [35] "Environment_Weather"         "Facemodels"
# ...

# %%
modl <- glm(Pop1 ~. - Mod - Udl - Pop1 - Pop10,family=binomial,data=data);
summary(modl);
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurred
# Call:
# glm(formula = Pop1 ~ . - Mod - Udl - Pop1 - Pop10, family = binomial,
#     data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.5211  -0.1370  -0.1124   0.0000   3.1624
#
# Coefficients:
#                               Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 -2.018e+01  7.118e+00  -2.835  0.00459 **
# time                         3.133e-04  2.629e-04   1.192  0.23338
# Chargen                     -2.489e+01  1.645e+04  -0.002  0.99879
# CompanionFriendly           -3.780e+01  4.925e+03  -0.008  0.99388
# Companions                   4.833e+00  3.819e+00   1.265  0.20574
# Compilation                 -2.829e+01  1.721e+04  -0.002  0.99869
# Forfemalecharacters         -5.165e+01  3.071e+03  -0.017  0.98658
# Formalecharacters            5.057e+00  3.243e+00   1.559  0.11896
# ...

# %%
modl2 <- glm(Pop10 ~ . - Mod - Udl - Pop1 - Pop10,family=binomial,data=data);
summary(modl2);
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurred
# Call:
# glm(formula = Pop10 ~ . - Mod - Udl - Pop1 - Pop10, family = binomial,
#     data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6218  -0.4669  -0.4060  -0.3653   2.6425
#
# Coefficients:
#                               Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 -2.778e+00  3.023e-01  -9.189  < 2e-16 ***
# time                         2.144e-04  7.512e-05   2.854  0.00431 **
# Chargen                      8.466e-02  1.199e+00   0.071  0.94370
# CompanionFriendly           -6.760e-01  4.834e-01  -1.399  0.16193
# Companions                  -8.273e-01  7.169e-01  -1.154  0.24853
# Compilation                 -1.065e+00  1.611e+00  -0.661  0.50850
# Forfemalecharacters          1.468e-01  4.359e-01   0.337  0.73626
# Formalecharacters            2.984e-02  4.740e-01   0.063  0.94981
# ...

# %%
anova(modl, test="Chi");
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# ...

# %%
anova(modl2, test="Chi");
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# ...

# %%
drop1(modl, test="Chi");
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: algorithm did not convergeWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# ...

# %%
drop1(modl2, test="Chi");
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# ...
