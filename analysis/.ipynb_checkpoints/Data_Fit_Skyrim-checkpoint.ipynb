# %%
f = read.csv("fit_data.csv");

# %%
vars = cbind(f$Mod, f$Udl, f$Pop1, f$Pop10, f$Anime,f$LoreFriendly,f$NotLoreFriendly,f$SexySkimpy,f$Creatures,f$PlantsFoliage,f$AnimationModified,f$AnimationNew,f$EnvironmentOther,f$Facemodels,f$EnvironmentWeather,f$LeveledLists,f$Newmodels,f$Newtextures,f$ScriptedEvents,f$Chargen,f$ENBPreset,f$GameplayEffectsChanges,f$Official,f$PerformanceOptimization,f$Replacer,f$none,f$NotSafeForWork,f$Nudity,f$Unrealistic,f$ArmorShields,f$Clothing,f$ClothingFemale,f$CreaturesRideable,f$LocationsPlayerOwned,f$NPCVendors,f$Weapons,f$Birthsigns,f$Hair,f$Quests,f$Formalecharacters,f$RelatedtoMoviesTVOtherGames,f$FairandBalanced);
colf = c("Mod", "Udl", "Pop1", "Pop10", "Anime","LoreFriendly","NotLoreFriendly","SexySkimpy","Creatures","PlantsFoliage","AnimationModified","AnimationNew","EnvironmentOther","Facemodels","EnvironmentWeather","LeveledLists","Newmodels","Newtextures","ScriptedEvents","Chargen","ENBPreset","GameplayEffectsChanges","Official","PerformanceOptimization","Replacer","none","NotSafeForWork","Nudity","Unrealistic","ArmorShields","Clothing","ClothingFemale","CreaturesRideable","LocationsPlayerOwned","NPCVendors","Weapons","Birthsigns","Hair","Quests","Formalecharacters","RelatedtoMoviesTVOtherGames","FairandBalanced");

dimnames(vars)[[2]] <- colf
data <- data.frame(vars);

dim(vars)
# Out:
# [1] 39740    42

# %%
summary(data);
# Out:
#       Mod             Udl               Pop1             Pop10
#  Min.   :    8   Min.   :      0   Min.   :0.00000   Min.   :0.0
#  1st Qu.:16208   1st Qu.:    241   1st Qu.:0.00000   1st Qu.:0.0
#  Median :31784   Median :    733   Median :0.00000   Median :0.0
#  Mean   :34239   Mean   :  10818   Mean   :0.01002   Mean   :0.1
#  3rd Qu.:54016   3rd Qu.:   2813   3rd Qu.:0.00000   3rd Qu.:0.0
#  Max.   :70742   Max.   :8224648   Max.   :1.00000   Max.   :1.0
#      Anime          LoreFriendly    NotLoreFriendly     SexySkimpy
#  Min.   :0.00000   Min.   :0.0000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.0000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.0000   Median :0.00000   Median :0.00000
#  Mean   :0.01799   Mean   :0.2167   Mean   :0.05159   Mean   :0.03186
#  3rd Qu.:0.00000   3rd Qu.:0.0000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.0000   Max.   :1.00000   Max.   :1.00000
#    Creatures       PlantsFoliage     AnimationModified   AnimationNew
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.00000   Median :0.00000   Median :0.000000   Median :0.000000
#  Mean   :0.02776   Mean   :0.01137   Mean   :0.009159   Mean   :0.006769
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.000000   Max.   :1.000000
#  EnvironmentOther   Facemodels     EnvironmentWeather  LeveledLists
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.000000   Min.   :0.00000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.000000   1st Qu.:0.00000
#  Median :0.0000   Median :0.0000   Median :0.000000   Median :0.00000
#  Mean   :0.0308   Mean   :0.0194   Mean   :0.008606   Mean   :0.01296
#  3rd Qu.:0.0000   3rd Qu.:0.0000   3rd Qu.:0.000000   3rd Qu.:0.00000
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.000000   Max.   :1.00000
#    Newmodels        Newtextures     ScriptedEvents       Chargen
#  Min.   :0.00000   Min.   :0.0000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.0000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.0000   Median :0.00000   Median :0.00000
#  Mean   :0.05687   Mean   :0.1133   Mean   :0.01895   Mean   :0.01422
#  3rd Qu.:0.00000   3rd Qu.:0.0000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.0000   Max.   :1.00000   Max.   :1.00000
#    ENBPreset        GameplayEffectsChanges    Official
#  Min.   :0.000000   Min.   :0.00000        Min.   :0.00000
#  1st Qu.:0.000000   1st Qu.:0.00000        1st Qu.:0.00000
#  Median :0.000000   Median :0.00000        Median :0.00000
#  Mean   :0.001912   Mean   :0.09331        Mean   :0.00614
#  3rd Qu.:0.000000   3rd Qu.:0.00000        3rd Qu.:0.00000
#  Max.   :1.000000   Max.   :1.00000        Max.   :1.00000
#  PerformanceOptimization    Replacer            none        NotSafeForWork
#  Min.   :0.0000          Min.   :0.00000   Min.   :0.0000   Min.   :0.000000
#  1st Qu.:0.0000          1st Qu.:0.00000   1st Qu.:0.0000   1st Qu.:0.000000
#  Median :0.0000          Median :0.00000   Median :0.0000   Median :0.000000
#  Mean   :0.0152          Mean   :0.08216   Mean   :0.2769   Mean   :0.007147
#  3rd Qu.:0.0000          3rd Qu.:0.00000   3rd Qu.:1.0000   3rd Qu.:0.000000
#  Max.   :1.0000          Max.   :1.00000   Max.   :1.0000   Max.   :1.000000
#      Nudity         Unrealistic       ArmorShields        Clothing
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.00000
#  Mean   :0.00843   Mean   :0.02579   Mean   :0.04092   Mean   :0.04479
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#  ClothingFemale    CreaturesRideable LocationsPlayerOwned   NPCVendors
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000      Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000      1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000      Median :0.00000
#  Mean   :0.03593   Mean   :0.00692   Mean   :0.04909      Mean   :0.02448
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000      3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000      Max.   :1.00000
#     Weapons          Birthsigns            Hair             Quests
#  Min.   :0.00000   Min.   :0.000000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.000000   Median :0.00000   Median :0.00000
#  Mean   :0.09165   Mean   :0.001485   Mean   :0.01002   Mean   :0.02121
#  3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.000000   Max.   :1.00000   Max.   :1.00000
#  Formalecharacters RelatedtoMoviesTVOtherGames FairandBalanced
#  Min.   :0.00000   Min.   :0.00000             Min.   :0.000
#  1st Qu.:0.00000   1st Qu.:0.00000             1st Qu.:0.000
#  Median :0.00000   Median :0.00000             Median :0.000
#  Mean   :0.08988   Mean   :0.02559             Mean   :0.178
#  3rd Qu.:0.00000   3rd Qu.:0.00000             3rd Qu.:0.000
#  Max.   :1.00000   Max.   :1.00000             Max.   :1.000

# %%
# Define a function
hiCor <- function(x, level){
  res <- cor(x,method="spearman");
  res1 <- res; res1[res<0] <- -res[res < 0];
  for (i in 1:dim(x)[2]){
    res1[i,i] <- 0;
  }
  sel <- apply(res1,1,max) > level;
  res[sel,sel];
}
hiCor(data,.6)
# Out:
#                 Clothing ClothingFemale
# Clothing       1.0000000      0.6144248
# ClothingFemale 0.6144248      1.0000000

# %%
plot(1:42,cumsum(prcomp(vars, retx=F,scale=T)$sdev^2)/sum(prcomp(vars, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title

# %%
res<-prcomp(vars, retx=F,scale=T)$rotation[,1:3];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:3)
  print(t(res[resAbs[,i]>.1,i,drop=FALSE]));
# Out:
#           Udl      Pop1     Pop10 LoreFriendly Creatures PlantsFoliage
# PC1 0.1800688 0.1787159 0.2024387    0.2578208 0.1371329      0.148995
#     AnimationModified AnimationNew EnvironmentOther Facemodels
# PC1         0.1276019    0.1355306        0.1372456  0.1085577
#     EnvironmentWeather LeveledLists Newmodels Newtextures ScriptedEvents
# PC1          0.1074028    0.1477183 0.2324924   0.2308999      0.1657002
#     GameplayEffectsChanges Official PerformanceOptimization  Replacer
# PC1              0.1370843 0.112918               0.1033256 0.1497439
#           none ArmorShields  Clothing ClothingFemale CreaturesRideable
# PC1 -0.2858235    0.1875093 0.2152824      0.2043347         0.1115174
#     LocationsPlayerOwned NPCVendors   Weapons Birthsigns      Hair    Quests
# PC1            0.1046201   0.161473 0.1787485   0.101875 0.1095916 0.1567708
#     Formalecharacters RelatedtoMoviesTVOtherGames FairandBalanced
# PC1         0.1708108                   0.1167405       0.2481915
#           Udl      Pop1      Anime LoreFriendly NotLoreFriendly SexySkimpy
# PC2 0.1068139 0.1079922 -0.2439444    0.1688719      -0.3348417 -0.3632669
#     PlantsFoliage EnvironmentOther EnvironmentWeather ScriptedEvents
# PC2     0.1410201        0.1851569          0.1369148      0.1535858
#     GameplayEffectsChanges PerformanceOptimization NotSafeForWork     Nudity
# PC2               0.185839               0.1289605     -0.2916215 -0.2523926
#     Unrealistic   Clothing ClothingFemale LocationsPlayerOwned NPCVendors
# PC2  -0.2919165 -0.1809718     -0.2447461            0.1480925  0.1156876
#        Quests Formalecharacters RelatedtoMoviesTVOtherGames FairandBalanced
# PC2 0.1282144        -0.1276818                  -0.1112977       0.1479553
#           Mod        Udl       Pop1      Pop10      Anime LoreFriendly
# PC3 0.1520917 -0.3528562 -0.3629423 -0.2691905 -0.1142982    0.1683751
#     SexySkimpy AnimationModified AnimationNew EnvironmentOther Facemodels
# PC3 -0.1494505        -0.2246516   -0.2029603         -0.13874 -0.1076246
#     EnvironmentWeather    Chargen PerformanceOptimization       none
# PC3         -0.1605597 -0.1131581              -0.1676141 -0.1047976
#     NotSafeForWork     Nudity Unrealistic ArmorShields  Clothing ClothingFemale
# PC3     -0.1557802 -0.1239567  -0.1421922    0.2356133 0.2309791       0.173358
#     LocationsPlayerOwned   Weapons Formalecharacters FairandBalanced
# PC3            0.1032299 0.2117878          0.214406       0.1616022

# %%
modl <- glm(Pop1 ~ ...,family=binomial,data=data);
summary(modl);
# Out:
# Call:
# glm(formula = Pop1 ~ Anime + LoreFriendly + NotLoreFriendly +
#     SexySkimpy + Creatures + PlantsFoliage + AnimationModified +
#     AnimationNew + EnvironmentOther + Facemodels + EnvironmentWeather +
#     LeveledLists + Newmodels + Newtextures + ScriptedEvents +
#     Chargen + ENBPreset + GameplayEffectsChanges + Official +
#     PerformanceOptimization + Replacer + none + NotSafeForWork +
#     Nudity + Unrealistic + ArmorShields + Clothing + ClothingFemale +
#     CreaturesRideable + LocationsPlayerOwned + NPCVendors + Weapons +
#     Birthsigns + Hair + Quests + Formalecharacters + RelatedtoMoviesTVOtherGames +
#     FairandBalanced, family = binomial, data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1931  -0.1232  -0.0725  -0.0191   4.1504
#
# Coefficients:
#                             Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 -5.94007    0.11642 -51.024  < 2e-16 ***
# Anime                        0.74385    0.30066   2.474 0.013360 *
# LoreFriendly                 1.00709    0.12347   8.157 3.45e-16 ***
# NotLoreFriendly              0.22245    0.24500   0.908 0.363895
# SexySkimpy                   0.72619    0.23568   3.081 0.002062 **
# Creatures                   -0.07588    0.22815  -0.333 0.739441
# PlantsFoliage                0.31997    0.28482   1.123 0.261251
# AnimationModified            1.20592    0.26246   4.595 4.33e-06 ***
# AnimationNew                 0.95837    0.29395   3.260 0.001113 **
# EnvironmentOther             0.74604    0.18261   4.085 4.40e-05 ***
# Facemodels                   0.15803    0.24313   0.650 0.515689
# EnvironmentWeather           0.45306    0.28820   1.572 0.115950
# LeveledLists                 0.64986    0.23753   2.736 0.006222 **
# Newmodels                    0.28686    0.16247   1.766 0.077470 .
# Newtextures                  0.87411    0.13673   6.393 1.63e-10 ***
# ScriptedEvents               0.68298    0.21538   3.171 0.001519 **
# Chargen                      1.40829    0.21162   6.655 2.83e-11 ***
# ENBPreset                    2.10052    0.45009   4.667 3.06e-06 ***
# GameplayEffectsChanges       0.80745    0.13476   5.992 2.07e-09 ***
# Official                    -2.32631    0.53908  -4.315 1.59e-05 ***
# PerformanceOptimization      1.29315    0.18829   6.868 6.51e-12 ***
# Replacer                     0.93685    0.13010   7.201 5.97e-13 ***
# none                        -2.67271    0.71668  -3.729 0.000192 ***
# NotSafeForWork               0.68496    0.42466   1.613 0.106751
# Nudity                      -0.82293    0.57446  -1.433 0.151995
# Unrealistic                  0.35233    0.27289   1.291 0.196668
# ArmorShields                 0.36544    0.21488   1.701 0.089008 .
# Clothing                     0.03626    0.25889   0.140 0.888602
# ClothingFemale              -0.13513    0.28182  -0.480 0.631574
# CreaturesRideable           -0.14339    0.46270  -0.310 0.756648
# LocationsPlayerOwned        -0.66859    0.26851  -2.490 0.012773 *
# NPCVendors                   0.24164    0.24463   0.988 0.323244
# Weapons                     -0.36525    0.17805  -2.051 0.040233 *
# Birthsigns                  -4.01424    0.95642  -4.197 2.70e-05 ***
# Hair                         0.54403    0.29163   1.865 0.062116 .
# Quests                       0.31867    0.25613   1.244 0.213430
# Formalecharacters           -0.39965    0.17873  -2.236 0.025353 *
# RelatedtoMoviesTVOtherGames -0.64350    0.32283  -1.993 0.046228 *
# FairandBalanced              0.51423    0.12301   4.180 2.91e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 4456.5  on 39739  degrees of freedom
# Residual deviance: 3356.2  on 39701  degrees of freedom
# AIC: 3434.2
#
# Number of Fisher Scoring iterations: 11

# %%
modl2 <- glm(Pop10 ~ ...,family=binomial,data=data);
summary(modl2);
# Out:
# Call:
# glm(formula = Pop10 ~ Anime + LoreFriendly + NotLoreFriendly +
#     SexySkimpy + Creatures + PlantsFoliage + AnimationModified +
#     AnimationNew + EnvironmentOther + Facemodels + EnvironmentWeather +
#     LeveledLists + Newmodels + Newtextures + ScriptedEvents +
#     Chargen + ENBPreset + GameplayEffectsChanges + Official +
#     PerformanceOptimization + Replacer + none + NotSafeForWork +
#     Nudity + Unrealistic + ArmorShields + Clothing + ClothingFemale +
#     CreaturesRideable + LocationsPlayerOwned + NPCVendors + Weapons +
#     Birthsigns + Hair + Quests + Formalecharacters + RelatedtoMoviesTVOtherGames +
#     FairandBalanced, family = binomial, data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7855  -0.4648  -0.3631  -0.2590   3.2514
#
# Coefficients:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 -2.686254   0.032355 -83.024  < 2e-16 ***
# Anime                        0.802121   0.099934   8.026 1.00e-15 ***
# LoreFriendly                 0.444987   0.043592  10.208  < 2e-16 ***
# NotLoreFriendly             -0.008386   0.076762  -0.109 0.913004
# SexySkimpy                   0.944324   0.080689  11.703  < 2e-16 ***
# Creatures                   -0.101984   0.095544  -1.067 0.285791
# PlantsFoliage                0.092819   0.138134   0.672 0.501615
# AnimationModified            1.159516   0.135992   8.526  < 2e-16 ***
# AnimationNew                 0.969809   0.157496   6.158 7.38e-10 ***
# EnvironmentOther             0.512428   0.084485   6.065 1.32e-09 ***
# Facemodels                  -0.314180   0.121458  -2.587 0.009689 **
# EnvironmentWeather           0.346049   0.149851   2.309 0.020927 *
# LeveledLists                 0.225666   0.120633   1.871 0.061389 .
# Newmodels                    0.512251   0.062928   8.140 3.94e-16 ***
# Newtextures                  0.680701   0.051242  13.284  < 2e-16 ***
# ScriptedEvents               0.672021   0.097650   6.882 5.90e-12 ***
# Chargen                      0.549220   0.119636   4.591 4.42e-06 ***
# ENBPreset                    1.030693   0.279954   3.682 0.000232 ***
# GameplayEffectsChanges       0.515301   0.053737   9.589  < 2e-16 ***
# Official                    -2.110721   0.297059  -7.105 1.20e-12 ***
# PerformanceOptimization      0.846984   0.102817   8.238  < 2e-16 ***
# Replacer                     0.333855   0.054990   6.071 1.27e-09 ***
# none                        -0.691906   0.062415 -11.086  < 2e-16 ***
# NotSafeForWork               0.564071   0.153286   3.680 0.000233 ***
# Nudity                       0.116272   0.156719   0.742 0.458138
# Unrealistic                  0.567735   0.090049   6.305 2.89e-10 ***
# ArmorShields                -0.028392   0.084230  -0.337 0.736058
# Clothing                    -0.016906   0.091812  -0.184 0.853903
# ClothingFemale               0.520076   0.094018   5.532 3.17e-08 ***
# CreaturesRideable            0.290498   0.176430   1.647 0.099654 .
# LocationsPlayerOwned        -0.308178   0.087993  -3.502 0.000461 ***
# NPCVendors                   0.221883   0.099731   2.225 0.026094 *
# Weapons                     -0.120027   0.059835  -2.006 0.044861 *
# Birthsigns                  -3.195519   0.670731  -4.764 1.90e-06 ***
# Hair                         0.385401   0.143313   2.689 0.007162 **
# Quests                       0.292057   0.103924   2.810 0.004950 **
# Formalecharacters           -0.284515   0.062025  -4.587 4.49e-06 ***
# RelatedtoMoviesTVOtherGames  0.381788   0.089119   4.284 1.84e-05 ***
# FairandBalanced              0.085818   0.046751   1.836 0.066410 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 25838  on 39739  degrees of freedom
# Residual deviance: 22824  on 39701  degrees of freedom
# AIC: 22902
#
# Number of Fisher Scoring iterations: 6

# %%
anova(modl, test="Chi");
# Out:
# Analysis of Deviance Table
#
# Model: binomial, link: logit
#
# Response: Pop1
#
# Terms added sequentially (first to last)
#
#
#                             Df Deviance Resid. Df Resid. Dev  Pr(>Chi)
# NULL                                        39739     4456.5
# Anime                        1    13.97     39738     4442.5 0.0001860 ***
# LoreFriendly                 1   342.42     39737     4100.1 < 2.2e-16 ***
# NotLoreFriendly              1    12.95     39736     4087.2 0.0003203 ***
# SexySkimpy                   1    17.13     39735     4070.1 3.492e-05 ***
# Creatures                    1    15.45     39734     4054.6 8.481e-05 ***
# PlantsFoliage                1    21.97     39733     4032.6 2.767e-06 ***
# AnimationModified            1   101.50     39732     3931.1 < 2.2e-16 ***
# AnimationNew                 1    10.70     39731     3920.4 0.0010722 **
# EnvironmentOther             1    64.54     39730     3855.9 9.464e-16 ***
# Facemodels                   1    14.78     39729     3841.1 0.0001208 ***
# EnvironmentWeather           1     5.32     39728     3835.8 0.0210607 *
# LeveledLists                 1    11.15     39727     3824.6 0.0008381 ***
# Newmodels                    1    16.69     39726     3808.0 4.409e-05 ***
# Newtextures                  1    66.44     39725     3741.5 3.615e-16 ***
# ScriptedEvents               1    11.43     39724     3730.1 0.0007232 ***
# Chargen                      1    42.68     39723     3687.4 6.452e-11 ***
# ENBPreset                    1    18.56     39722     3668.8 1.645e-05 ***
# GameplayEffectsChanges       1    65.40     39721     3603.4 6.118e-16 ***
# Official                     1    32.11     39720     3571.3 1.457e-08 ***
# PerformanceOptimization      1    49.22     39719     3522.1 2.284e-12 ***
# Replacer                     1    50.29     39718     3471.8 1.325e-12 ***
# none                         1    38.55     39717     3433.3 5.331e-10 ***
# NotSafeForWork               1     2.18     39716     3431.1 0.1397822
# Nudity                       1     5.08     39715     3426.0 0.0242097 *
# Unrealistic                  1     2.17     39714     3423.8 0.1404780
# ArmorShields                 1     0.01     39713     3423.8 0.9383830
# Clothing                     1     0.90     39712     3422.9 0.3417345
# ClothingFemale               1     0.29     39711     3422.6 0.5931060
# CreaturesRideable            1     1.50     39710     3421.1 0.2210726
# LocationsPlayerOwned         1     5.58     39709     3415.6 0.0181229 *
# NPCVendors                   1     1.17     39708     3414.4 0.2786439
# Weapons                      1     4.55     39707     3409.8 0.0329581 *
# Birthsigns                   1    23.88     39706     3386.0 1.027e-06 ***
# Hair                         1     2.49     39705     3383.5 0.1147186
# Quests                       1     1.47     39704     3382.0 0.2258129
# Formalecharacters            1     4.22     39703     3377.8 0.0399431 *
# RelatedtoMoviesTVOtherGames  1     4.27     39702     3373.5 0.0386807 *
# FairandBalanced              1    17.33     39701     3356.2 3.146e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
anova(modl2, test="Chi");
# Out:
# Analysis of Deviance Table
#
# Model: binomial, link: logit
#
# Response: Pop10
#
# Terms added sequentially (first to last)
#
#
#                             Df Deviance Resid. Df Resid. Dev  Pr(>Chi)
# NULL                                        39739      25838
# Anime                        1   186.76     39738      25651 < 2.2e-16 ***
# LoreFriendly                 1   602.65     39737      25048 < 2.2e-16 ***
# NotLoreFriendly              1    81.87     39736      24966 < 2.2e-16 ***
# SexySkimpy                   1   296.07     39735      24670 < 2.2e-16 ***
# Creatures                    1    23.86     39734      24646 1.038e-06 ***
# PlantsFoliage                1    30.94     39733      24615 2.664e-08 ***
# AnimationModified            1   223.15     39732      24392 < 2.2e-16 ***
# AnimationNew                 1    54.92     39731      24337 1.258e-13 ***
# EnvironmentOther             1   122.40     39730      24215 < 2.2e-16 ***
# Facemodels                   1     1.01     39729      24214 0.3141095
# EnvironmentWeather           1    14.43     39728      24200 0.0001454 ***
# LeveledLists                 1    25.13     39727      24174 5.359e-07 ***
# Newmodels                    1   252.31     39726      23922 < 2.2e-16 ***
# Newtextures                  1   277.26     39725      23645 < 2.2e-16 ***
# ScriptedEvents               1    81.81     39724      23563 < 2.2e-16 ***
# Chargen                      1    24.85     39723      23538 6.195e-07 ***
# ENBPreset                    1    15.85     39722      23522 6.868e-05 ***
# GameplayEffectsChanges       1   156.34     39721      23366 < 2.2e-16 ***
# Official                     1    72.11     39720      23294 < 2.2e-16 ***
# PerformanceOptimization      1    71.47     39719      23222 < 2.2e-16 ***
# Replacer                     1    47.65     39718      23175 5.090e-12 ***
# none                         1   143.49     39717      23031 < 2.2e-16 ***
# NotSafeForWork               1    23.81     39716      23008 1.061e-06 ***
# Nudity                       1     0.22     39715      23007 0.6354971
# Unrealistic                  1    39.95     39714      22967 2.601e-10 ***
# ArmorShields                 1     0.63     39713      22967 0.4270674
# Clothing                     1    12.65     39712      22954 0.0003764 ***
# ClothingFemale               1    27.89     39711      22926 1.284e-07 ***
# CreaturesRideable            1     1.37     39710      22925 0.2413602
# LocationsPlayerOwned         1     8.39     39709      22916 0.0037708 **
# NPCVendors                   1     5.96     39708      22910 0.0146335 *
# Weapons                      1     2.21     39707      22908 0.1368302
# Birthsigns                   1    27.75     39706      22880 1.382e-07 ***
# Hair                         1     5.98     39705      22874 0.0144936 *
# Quests                       1     8.20     39704      22866 0.0041877 **
# Formalecharacters            1    20.43     39703      22846 6.183e-06 ***
# RelatedtoMoviesTVOtherGames  1    18.05     39702      22828 2.151e-05 ***
# FairandBalanced              1     3.35     39701      22824 0.0671546 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
drop1(modl, test="Chi");
# Out:
# Single term deletions
#
# Model:
# Pop1 ~ Anime + LoreFriendly + NotLoreFriendly + SexySkimpy +
#     Creatures + PlantsFoliage + AnimationModified + AnimationNew +
#     EnvironmentOther + Facemodels + EnvironmentWeather + LeveledLists +
#     Newmodels + Newtextures + ScriptedEvents + Chargen + ENBPreset +
#     GameplayEffectsChanges + Official + PerformanceOptimization +
#     Replacer + none + NotSafeForWork + Nudity + Unrealistic +
#     ArmorShields + Clothing + ClothingFemale + CreaturesRideable +
#     LocationsPlayerOwned + NPCVendors + Weapons + Birthsigns +
#     Hair + Quests + Formalecharacters + RelatedtoMoviesTVOtherGames +
#     FairandBalanced
#                             Df Deviance    AIC    LRT  Pr(>Chi)
# <none>                           3356.2 3434.2
# Anime                        1   3361.6 3437.6  5.420  0.019905 *
# LoreFriendly                 1   3424.7 3500.7 68.559 < 2.2e-16 ***
# NotLoreFriendly              1   3357.0 3433.0  0.799  0.371442
# SexySkimpy                   1   3364.7 3440.7  8.493  0.003565 **
# Creatures                    1   3356.3 3432.3  0.112  0.737645
# PlantsFoliage                1   3357.4 3433.4  1.205  0.272330
# AnimationModified            1   3375.1 3451.1 18.899 1.378e-05 ***
# AnimationNew                 1   3366.0 3442.0  9.791  0.001753 **
# EnvironmentOther             1   3371.4 3447.4 15.178 9.786e-05 ***
# Facemodels                   1   3356.6 3432.6  0.414  0.519827
# EnvironmentWeather           1   3358.5 3434.5  2.351  0.125236
# LeveledLists                 1   3362.9 3438.9  6.731  0.009475 **
# Newmodels                    1   3359.2 3435.2  3.024  0.082026 .
# Newtextures                  1   3395.7 3471.7 39.532 3.227e-10 ***
# ScriptedEvents               1   3365.4 3441.4  9.213  0.002403 **
# Chargen                      1   3392.8 3468.8 36.633 1.426e-09 ***
# ENBPreset                    1   3372.0 3448.0 15.765 7.173e-05 ***
# GameplayEffectsChanges       1   3389.8 3465.8 33.617 6.710e-09 ***
# Official                     1   3382.3 3458.3 26.133 3.187e-07 ***
# PerformanceOptimization      1   3396.0 3472.0 39.855 2.735e-10 ***
# Replacer                     1   3404.1 3480.1 47.942 4.391e-12 ***
# none                         1   3391.8 3467.8 35.623 2.395e-09 ***
# NotSafeForWork               1   3358.5 3434.5  2.335  0.126524
# Nudity                       1   3358.5 3434.5  2.349  0.125375
# Unrealistic                  1   3357.8 3433.8  1.588  0.207589
# ArmorShields                 1   3358.9 3434.9  2.732  0.098340 .
# Clothing                     1   3356.2 3432.2  0.020  0.888855
# ClothingFemale               1   3356.4 3432.4  0.232  0.630045
# CreaturesRideable            1   3356.3 3432.3  0.098  0.753661
# LocationsPlayerOwned         1   3363.2 3439.2  7.033  0.008003 **
# NPCVendors                   1   3357.1 3433.1  0.938  0.332882
# Weapons                      1   3360.6 3436.6  4.460  0.034697 *
# Birthsigns                   1   3377.4 3453.4 21.213 4.109e-06 ***
# Hair                         1   3359.4 3435.4  3.220  0.072727 .
# Quests                       1   3357.7 3433.7  1.475  0.224502
# Formalecharacters            1   3361.5 3437.5  5.342  0.020817 *
# RelatedtoMoviesTVOtherGames  1   3360.7 3436.7  4.560  0.032734 *
# FairandBalanced              1   3373.5 3449.5 17.328 3.146e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
drop1(modl2, test="Chi");
# Out:
# Single term deletions
#
# Model:
# Pop10 ~ Anime + LoreFriendly + NotLoreFriendly + SexySkimpy +
#     Creatures + PlantsFoliage + AnimationModified + AnimationNew +
#     EnvironmentOther + Facemodels + EnvironmentWeather + LeveledLists +
#     Newmodels + Newtextures + ScriptedEvents + Chargen + ENBPreset +
#     GameplayEffectsChanges + Official + PerformanceOptimization +
#     Replacer + none + NotSafeForWork + Nudity + Unrealistic +
#     ArmorShields + Clothing + ClothingFemale + CreaturesRideable +
#     LocationsPlayerOwned + NPCVendors + Weapons + Birthsigns +
#     Hair + Quests + Formalecharacters + RelatedtoMoviesTVOtherGames +
#     FairandBalanced
#                             Df Deviance   AIC     LRT  Pr(>Chi)
# <none>                            22824 22902
# Anime                        1    22884 22960  59.186 1.434e-14 ***
# LoreFriendly                 1    22927 23003 102.429 < 2.2e-16 ***
# NotLoreFriendly              1    22824 22900   0.012 0.9129572
# SexySkimpy                   1    22950 23026 125.358 < 2.2e-16 ***
# Creatures                    1    22826 22902   1.159 0.2817404
# PlantsFoliage                1    22825 22901   0.446 0.5041585
# AnimationModified            1    22891 22967  66.521 3.462e-16 ***
# AnimationNew                 1    22860 22936  36.113 1.862e-09 ***
# EnvironmentOther             1    22859 22935  34.592 4.065e-09 ***
# Facemodels                   1    22831 22907   6.991 0.0081943 **
# EnvironmentWeather           1    22830 22906   5.144 0.0233280 *
# LeveledLists                 1    22828 22904   3.396 0.0653712 .
# Newmodels                    1    22888 22964  63.620 1.509e-15 ***
# Newtextures                  1    22994 23070 169.863 < 2.2e-16 ***
# ScriptedEvents               1    22869 22945  44.298 2.820e-11 ***
# Chargen                      1    22844 22920  19.508 1.002e-05 ***
# ENBPreset                    1    22836 22912  11.778 0.0005992 ***
# GameplayEffectsChanges       1    22912 22988  87.048 < 2.2e-16 ***
# Official                     1    22898 22974  73.971 < 2.2e-16 ***
# PerformanceOptimization      1    22886 22962  61.563 4.288e-15 ***
# Replacer                     1    22860 22936  35.633 2.383e-09 ***
# none                         1    22960 23036 135.054 < 2.2e-16 ***
# NotSafeForWork               1    22837 22913  13.028 0.0003069 ***
# Nudity                       1    22825 22901   0.543 0.4610425
# Unrealistic                  1    22862 22938  37.575 8.795e-10 ***
# ArmorShields                 1    22824 22900   0.114 0.7355717
# Clothing                     1    22824 22900   0.034 0.8537851
# ClothingFemale               1    22854 22930  29.996 4.330e-08 ***
# CreaturesRideable            1    22827 22903   2.599 0.1069046
# LocationsPlayerOwned         1    22837 22913  12.974 0.0003158 ***
# NPCVendors                   1    22829 22905   4.794 0.0285649 *
# Weapons                      1    22828 22904   4.088 0.0431825 *
# Birthsigns                   1    22856 22932  31.312 2.197e-08 ***
# Hair                         1    22831 22907   6.912 0.0085638 **
# Quests                       1    22832 22908   7.586 0.0058821 **
# Formalecharacters            1    22846 22922  21.924 2.836e-06 ***
# RelatedtoMoviesTVOtherGames  1    22842 22918  17.434 2.974e-05 ***
# FairandBalanced              1    22828 22904   3.351 0.0671546 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
