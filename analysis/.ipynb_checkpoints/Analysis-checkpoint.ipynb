# %% [markdown]
# #Analysis on Skyrim Data

# %%
f = read.csv("skyrim.csv");

vars = cbind( f$likes, f$downloads, f$time, f$unique_dl, f$views);

dimnames(vars)[[2]] <- c("likes", "downloads", "time", "unique_dl", "views");

data <- data.frame(vars);

# %%
summary(data);
# Out:
#      likes            downloads             time          unique_dl
#  Min.   :     0.0   Min.   :       0   Min.   :  10.0   Min.   :      0
#  1st Qu.:    15.0   1st Qu.:     329   1st Qu.: 533.0   1st Qu.:    241
#  Median :    46.0   Median :    1035   Median : 985.0   Median :    733
#  Mean   :   586.8   Mean   :   17080   Mean   : 888.4   Mean   :  10818
#  3rd Qu.:   172.0   3rd Qu.:    3986   3rd Qu.:1277.0   3rd Qu.:   2813
#  Max.   :351178.0   Max.   :17112581   Max.   :1450.0   Max.   :8224648
#      views
#  Min.   :     187
#  1st Qu.:    8103
#  Median :   16528
#  Mean   :   66737
#  3rd Qu.:   38798
#  Max.   :24564770

# %%
cor(vars, use="pairwise.complete.obs", method="spearman");
# Out:
#               likes downloads      time unique_dl     views
# likes     1.0000000 0.9427059 0.1335574 0.9521003 0.8104138
# downloads 0.9427059 1.0000000 0.3251242 0.9969031 0.8907925
# time      0.1335574 0.3251242 1.0000000 0.2891657 0.4150054
# unique_dl 0.9521003 0.9969031 0.2891657 1.0000000 0.8887670
# views     0.8104138 0.8907925 0.4150054 0.8887670 1.0000000

# %%
res<-prcomp(vars, retx=F,scale=T, na.action = na.omit)$rotation[,1:3];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:3)
  print(t(res[resAbs[,i]>.3,i,drop=FALSE]));
# Out:
#          likes  downloads  unique_dl      views
# PC1 -0.4895757 -0.5012044 -0.5065418 -0.5001993
#          time
# PC2 0.9984381
#          likes downloads unique_dl
# PC3 -0.7488388 0.5369964 0.3527427

# %%
plot(1:5,cumsum(prcomp(vars, retx=F,scale=T)$sdev^2)/sum(prcomp(vars, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title

# %% [markdown]
# #Analysis of Oblivion Data

# %%
f = read.csv("oblivion.csv");

vars = cbind( f$likes, f$downloads, f$time, f$unique_dl, f$views);

dimnames(vars)[[2]] <- c("likes", "downloads", "time", "unique_dl", "views");

data <- data.frame(vars);

# %%
summary(data);
# Out:
#      likes            downloads            time        unique_dl
#  Min.   :    0.00   Min.   :      0   Min.   :   6   Min.   :     0
#  1st Qu.:    5.00   1st Qu.:    178   1st Qu.:1799   1st Qu.:   140
#  Median :   15.00   Median :    515   Median :2402   Median :   401
#  Mean   :   78.88   Mean   :   4533   Mean   :2345   Mean   :  2928
#  3rd Qu.:   47.00   3rd Qu.:   1706   3rd Qu.:3058   3rd Qu.:  1299
#  Max.   :27545.00   Max.   :1742557   Max.   :3832   Max.   :964238
#      views
#  Min.   :    113
#  1st Qu.:   4498
#  Median :   8529
#  Mean   :  23015
#  3rd Qu.:  18633
#  Max.   :4392937

# %%
cor(vars,method="spearman");
# Out:
#               likes downloads      time unique_dl     views
# likes     1.0000000 0.8969722 0.0620114 0.8972531 0.7838634
# downloads 0.8969722 1.0000000 0.1542028 0.9986377 0.8774390
# time      0.0620114 0.1542028 1.0000000 0.1564379 0.1862039
# unique_dl 0.8972531 0.9986377 0.1564379 1.0000000 0.8777410
# views     0.7838634 0.8774390 0.1862039 0.8777410 1.0000000

# %%
res<-prcomp(vars, retx=F,scale=T)$rotation[,1:3];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:3)
  print(t(res[resAbs[,i]>.3,i,drop=FALSE]));
# Out:
#          likes  downloads  unique_dl     views
# PC1 -0.4891621 -0.4985799 -0.5106752 -0.499003
#           time
# PC2 -0.9979894
#          likes downloads unique_dl      views
# PC3 -0.6264962 0.5984977 0.3575639 -0.3480367

# %%
plot(1:5,cumsum(prcomp(vars, retx=F,scale=T)$sdev^2)/sum(prcomp(vars, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title

# %% [markdown]
# #Analysis of Morrowind Data

# %%
f = read.csv("morrowind.csv");

vars = cbind( f$likes, f$downloads, f$time, f$unique_dl, f$views);

dimnames(vars)[[2]] <- c("likes", "downloads", "time", "unique_dl", "views");

data <- data.frame(vars);

# %%
summary(data);
# Out:
#      likes            downloads             time          unique_dl
#  Min.   :    0.00   Min.   :     0.0   Min.   :   7.0   Min.   :     0.0
#  1st Qu.:    5.00   1st Qu.:   113.0   1st Qu.: 704.5   1st Qu.:    92.0
#  Median :   13.00   Median :   275.0   Median :1791.0   Median :   218.0
#  Mean   :   72.46   Mean   :  1742.6   Mean   :1823.0   Mean   :  1351.6
#  3rd Qu.:   41.00   3rd Qu.:   821.5   3rd Qu.:2946.5   3rd Qu.:   648.5
#  Max.   :10179.00   Max.   :268100.0   Max.   :4342.0   Max.   :199165.0
#      views
#  Min.   :    100
#  1st Qu.:   2676
#  Median :   4715
#  Mean   :  11244
#  3rd Qu.:   9039
#  Max.   :1212512

# %%
cor(vars,method="spearman");
# Out:
#                  likes downloads         time unique_dl     views
# likes      1.000000000 0.9076319 -0.002151617 0.9080815 0.7832266
# downloads  0.907631925 1.0000000  0.200155500 0.9956010 0.8754673
# time      -0.002151617 0.2001555  1.000000000 0.2225778 0.3249613
# unique_dl  0.908081537 0.9956010  0.222577763 1.0000000 0.8869527
# views      0.783226603 0.8754673  0.324961349 0.8869527 1.0000000

# %%
res<-prcomp(vars, retx=F,scale=T)$rotation[,1:2];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:2)
  print(t(res[resAbs[,i]>.3,i,drop=FALSE]));
# Out:
#         likes downloads unique_dl     views
# PC1 0.4925681  0.504722 0.5027186 0.4992068
#           time
# PC2 -0.9987425

# %%
plot(1:5,cumsum(prcomp(vars, retx=F,scale=T)$sdev^2)/sum(prcomp(vars, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title
