# %%
f = read.csv("fit_data_o.csv");

# %%
vars = cbind(f$Mod, f$Udl, f$Pop1, f$Pop10, f$Anime,f$LoreFriendly,f$NotLoreFriendly,f$NotSafeForWork,f$Nudity,f$SexySkimpy,f$Unrealistic,f$ArmorShields,f$Books,f$Clothing,f$ClothingFemale,f$ClothingMale,f$Creatures,f$CreaturesRideable,f$ItemsApparatus,f$ItemsClutter,f$ItemsFurniture,f$ItemsIngredients,f$ItemsLeveled,f$LocationsBuildings,f$LocationsCaverns,f$LocationsDungeons,f$LocationsPlayerOwned,f$LocationsWorldMap,f$MagicEnchantments,f$MagicPotions,f$MagicSpells,f$NPCTrainers,f$NPCVendors,f$NPCs,f$PlantsFoliage,f$Weapons,f$AnimationModified,f$AnimationNew,f$AudioSoundFX,f$AudioVoices,f$Birthsigns,f$Bodymodels,f$Classescomponent,f$EnvironmentOther,f$EnvironmentSky,f$EnvironmentWater,f$EnvironmentWeather,f$Facemodels,f$GuildsFactions,f$Hair,f$LeveledLists,f$Lighting,f$NewLands,f$Newmodels,f$Newtextures,f$Quests,f$RacesModified,f$ScriptedEvents,f$Video,f$Chargen,f$CompanionFriendly,f$Companions,f$Compilation,f$ENBPreset,f$Forfemalecharacters,f$Formalecharacters,f$GameplayEffectsChanges,f$Official,f$PerformanceOptimization,f$Poses,f$Relatedtohorses,f$RelatedtoMoviesTVOtherGames,f$Relatedtovampires,f$Replacer,f$Cheating,f$Fairandbalanced,f$Unbalanced,f$BABBodybase,f$ECHGECBodybase,f$RobertFemaleBodybase,f$RobertMaleBodybase,f$TFFUFFBodybase);
colf = c("Mod", "Udl", "Pop1", "Pop10","Anime","LoreFriendly","NotLoreFriendly","NotSafeForWork","Nudity","SexySkimpy","Unrealistic","ArmorShields","Books","Clothing","ClothingFemale","ClothingMale","Creatures","CreaturesRideable","ItemsApparatus","ItemsClutter","ItemsFurniture","ItemsIngredients","ItemsLeveled","LocationsBuildings","LocationsCaverns","LocationsDungeons","LocationsPlayerOwned","LocationsWorldMap","MagicEnchantments","MagicPotions","MagicSpells","NPCTrainers","NPCVendors","NPCs","PlantsFoliage","Weapons","AnimationModified","AnimationNew","AudioSoundFX","AudioVoices","Birthsigns","Bodymodels","Classescomponent","EnvironmentOther","EnvironmentSky","EnvironmentWater","EnvironmentWeather","Facemodels","GuildsFactions","Hair","LeveledLists","Lighting","NewLands","Newmodels","Newtextures","Quests","RacesModified","ScriptedEvents","Video","Chargen","CompanionFriendly","Companions","Compilation","ENBPreset","Forfemalecharacters","Formalecharacters","GameplayEffectsChanges","Official","PerformanceOptimization","Poses","Relatedtohorses","RelatedtoMoviesTVOtherGames","Relatedtovampires","Replacer","Cheating","Fairandbalanced","Unbalanced","BABBodybase","ECHGECBodybase","RobertFemaleBodybase","RobertMaleBodybase","TFFUFFBodybase");

dimnames(vars)[[2]] <- colf
data <- data.frame(vars);

dim(vars)
# Out:
# [1] 26221    82

# %%
summary(data);
# Out:
#       Mod             Udl              Pop1             Pop10
#  Min.   :  937   Min.   :     0   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:11558   1st Qu.:   140   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :23543   Median :   401   Median :0.00000   Median :0.00000
#  Mean   :23643   Mean   :  2928   Mean   :0.01003   Mean   :0.09996
#  3rd Qu.:35806   3rd Qu.:  1299   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :46506   Max.   :964238   Max.   :1.00000   Max.   :1.00000
#      Anime           LoreFriendly     NotLoreFriendly    NotSafeForWork
#  Min.   :0.000000   Min.   :0.00000   Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.000000   Median :0.00000   Median :0.000000   Median :0.000000
#  Mean   :0.003356   Mean   :0.06628   Mean   :0.009992   Mean   :0.001335
#  3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.000000   Max.   :1.00000   Max.   :1.000000   Max.   :1.000000
#      Nudity           SexySkimpy       Unrealistic        ArmorShields
#  Min.   :0.000000   Min.   :0.00000   Min.   :0.000000   Min.   :0.00000
#  1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.00000
#  Median :0.000000   Median :0.00000   Median :0.000000   Median :0.00000
#  Mean   :0.008581   Mean   :0.01018   Mean   :0.003089   Mean   :0.02975
#  3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.00000
#  Max.   :1.000000   Max.   :1.00000   Max.   :1.000000   Max.   :1.00000
#      Books           Clothing       ClothingFemale     ClothingMale
#  Min.   :0.0000   Min.   :0.00000   Min.   :0.00000   Min.   :0.000000
#  1st Qu.:0.0000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000
#  Median :0.0000   Median :0.00000   Median :0.00000   Median :0.000000
#  Mean   :0.0164   Mean   :0.03875   Mean   :0.01724   Mean   :0.008619
#  3rd Qu.:0.0000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000
#  Max.   :1.0000   Max.   :1.00000   Max.   :1.00000   Max.   :1.000000
#    Creatures       CreaturesRideable  ItemsApparatus      ItemsClutter
#  Min.   :0.00000   Min.   :0.000000   Min.   :0.000000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.00000
#  Median :0.00000   Median :0.000000   Median :0.000000   Median :0.00000
#  Mean   :0.01758   Mean   :0.005644   Mean   :0.007094   Mean   :0.02368
#  3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.000000   Max.   :1.000000   Max.   :1.00000
#  ItemsFurniture    ItemsIngredients   ItemsLeveled      LocationsBuildings
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.000000   Min.   :0.000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.000
#  Median :0.00000   Median :0.00000   Median :0.000000   Median :0.000
#  Mean   :0.01228   Mean   :0.01217   Mean   :0.006331   Mean   :0.032
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.000000   Max.   :1.000
#  LocationsCaverns  LocationsDungeons LocationsPlayerOwned LocationsWorldMap
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.0000       Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.0000       1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.0000       Median :0.00000
#  Mean   :0.01083   Mean   :0.01819   Mean   :0.0431       Mean   :0.01991
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.0000       3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.0000       Max.   :1.00000
#  MagicEnchantments  MagicPotions       MagicSpells       NPCTrainers
#  Min.   :0.00000   Min.   :0.000000   Min.   :0.00000   Min.   :0.000000
#  1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.000000
#  Median :0.00000   Median :0.000000   Median :0.00000   Median :0.000000
#  Mean   :0.01365   Mean   :0.008772   Mean   :0.02342   Mean   :0.006598
#  3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.000000
#  Max.   :1.00000   Max.   :1.000000   Max.   :1.00000   Max.   :1.000000
#    NPCVendors           NPCs         PlantsFoliage         Weapons
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.000000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.000000   Median :0.00000
#  Mean   :0.02082   Mean   :0.04187   Mean   :0.008619   Mean   :0.06731
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.000000   Max.   :1.00000
#  AnimationModified   AnimationNew       AudioSoundFX       AudioVoices
#  Min.   :0.000000   Min.   :0.000000   Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.000000   Median :0.000000   Median :0.000000   Median :0.000000
#  Mean   :0.005644   Mean   :0.007856   Mean   :0.007246   Mean   :0.005988
#  3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.000000   Max.   :1.000000   Max.   :1.000000   Max.   :1.000000
#    Birthsigns         Bodymodels       Classescomponent   EnvironmentOther
#  Min.   :0.000000   Min.   :0.000000   Min.   :0.000000   Min.   :0.0000
#  1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.0000
#  Median :0.000000   Median :0.000000   Median :0.000000   Median :0.0000
#  Mean   :0.002555   Mean   :0.005492   Mean   :0.004462   Mean   :0.0132
#  3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.0000
#  Max.   :1.000000   Max.   :1.000000   Max.   :1.000000   Max.   :1.0000
#  EnvironmentSky     EnvironmentWater   EnvironmentWeather   Facemodels
#  Min.   :0.000000   Min.   :0.000000   Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.000000   Median :0.000000   Median :0.000000   Median :0.000000
#  Mean   :0.004004   Mean   :0.003204   Mean   :0.003852   Mean   :0.009839
#  3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.000000   Max.   :1.000000   Max.   :1.000000   Max.   :1.000000
#  GuildsFactions         Hair           LeveledLists         Lighting
#  Min.   :0.00000   Min.   :0.000000   Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.00000   Median :0.000000   Median :0.000000   Median :0.000000
#  Mean   :0.00942   Mean   :0.006789   Mean   :0.005721   Mean   :0.006064
#  3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.00000   Max.   :1.000000   Max.   :1.000000   Max.   :1.000000
#     NewLands         Newmodels        Newtextures          Quests
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.00000
#  Mean   :0.01239   Mean   :0.07479   Mean   :0.09996   Mean   :0.02426
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#  RacesModified      ScriptedEvents        Video             Chargen
#  Min.   :0.000000   Min.   :0.00000   Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.000000   Median :0.00000   Median :0.000000   Median :0.000000
#  Mean   :0.009649   Mean   :0.02143   Mean   :0.004882   Mean   :0.004119
#  3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.000000   Max.   :1.00000   Max.   :1.000000   Max.   :1.000000
#  CompanionFriendly   Companions       Compilation         ENBPreset
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.000000   Min.   :0.0000000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.0000000
#  Median :0.00000   Median :0.00000   Median :0.000000   Median :0.0000000
#  Mean   :0.01403   Mean   :0.02689   Mean   :0.007322   Mean   :0.0003051
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.0000000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.000000   Max.   :1.0000000
#  Forfemalecharacters Formalecharacters GameplayEffectsChanges    Official
#  Min.   :0.0000      Min.   :0.00000   Min.   :0.00000        Min.   :0.00000
#  1st Qu.:0.0000      1st Qu.:0.00000   1st Qu.:0.00000        1st Qu.:0.00000
#  Median :0.0000      Median :0.00000   Median :0.00000        Median :0.00000
#  Mean   :0.0696      Mean   :0.04737   Mean   :0.05129        Mean   :0.00164
#  3rd Qu.:0.0000      3rd Qu.:0.00000   3rd Qu.:0.00000        3rd Qu.:0.00000
#  Max.   :1.0000      Max.   :1.00000   Max.   :1.00000        Max.   :1.00000
#  PerformanceOptimization     Poses          Relatedtohorses
#  Min.   :0.000000        Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.000000        1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.000000        Median :0.000000   Median :0.000000
#  Mean   :0.006178        Mean   :0.001869   Mean   :0.007399
#  3rd Qu.:0.000000        3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.000000        Max.   :1.000000   Max.   :1.000000
#  RelatedtoMoviesTVOtherGames Relatedtovampires     Replacer
#  Min.   :0.00000             Min.   :0.000000   Min.   :0.00000
#  1st Qu.:0.00000             1st Qu.:0.000000   1st Qu.:0.00000
#  Median :0.00000             Median :0.000000   Median :0.00000
#  Mean   :0.01823             Mean   :0.009534   Mean   :0.03425
#  3rd Qu.:0.00000             3rd Qu.:0.000000   3rd Qu.:0.00000
#  Max.   :1.00000             Max.   :1.000000   Max.   :1.00000
#     Cheating      Fairandbalanced     Unbalanced        BABBodybase
#  Min.   :0.0000   Min.   :0.00000   Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.0000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.0000   Median :0.00000   Median :0.000000   Median :0.000000
#  Mean   :0.0151   Mean   :0.01712   Mean   :0.002632   Mean   :0.002746
#  3rd Qu.:0.0000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.0000   Max.   :1.00000   Max.   :1.000000   Max.   :1.000000
#  ECHGECBodybase    RobertFemaleBodybase RobertMaleBodybase TFFUFFBodybase
#  Min.   :0.00000   Min.   :0.00000      Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.00000   1st Qu.:0.00000      1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.00000   Median :0.00000      Median :0.000000   Median :0.000000
#  Mean   :0.03348   Mean   :0.00492      Mean   :0.008505   Mean   :0.005949
#  3rd Qu.:0.00000   3rd Qu.:0.00000      3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.00000   Max.   :1.00000      Max.   :1.000000   Max.   :1.000000

# %%
# Define a function
hiCor <- function(x, level){
  res <- cor(x,method="spearman");
  res1 <- res; res1[res<0] <- -res[res < 0];
  for (i in 1:dim(x)[2]){
    res1[i,i] <- 0;
  }
  sel <- apply(res1,1,max) > level;
  res[sel,sel];
}
hiCor(data,.6)
# Out:
#             Newmodels Newtextures
# Newmodels   1.0000000   0.6167657
# Newtextures 0.6167657   1.0000000

# %%
plot(1:82,cumsum(prcomp(vars, retx=F,scale=T)$sdev^2)/sum(prcomp(vars, retx=F,scale=T)$sdev^2),ylim=c(0,1),xlab="Number of coponents",ylab="Fraction of variance");
# Out:
# plot without title

# %%
res<-prcomp(vars, retx=F,scale=T)$rotation[,1:3];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:3)
  print(t(res[resAbs[,i]>.1,i,drop=FALSE]));
# Out:
#     LoreFriendly ArmorShields    Books  Clothing ClothingMale Creatures
# PC1    0.1392154    0.1621824 0.184251 0.1396673    0.1136788 0.1446511
#     ItemsApparatus ItemsClutter ItemsFurniture ItemsIngredients ItemsLeveled
# PC1      0.1575748    0.1664846      0.1490357        0.1852022    0.1394803
#     LocationsBuildings LocationsCaverns LocationsDungeons LocationsPlayerOwned
# PC1          0.1787306        0.1793641          0.196644            0.1268801
#     LocationsWorldMap MagicEnchantments MagicPotions MagicSpells NPCTrainers
# PC1         0.1737498         0.1357815    0.1655613    0.124717   0.1639552
#     NPCVendors      NPCs PlantsFoliage   Weapons AudioSoundFX AudioVoices
# PC1  0.1777347 0.1887248     0.1389319 0.1525409     0.115203   0.1197724
#     GuildsFactions  NewLands Newmodels Newtextures Quests ScriptedEvents
# PC1      0.1468862 0.1528206 0.1455399   0.1466697  0.181      0.1523167
#     Forfemalecharacters Formalecharacters
# PC1           0.1316936         0.1576922
#         Pop10     Anime NotLoreFriendly NotSafeForWork    Nudity SexySkimpy
# PC2 0.1216452 0.1863732       0.2502402      0.1438109 0.1350077   0.271818
#     Unrealistic  Clothing ClothingFemale ClothingMale LocationsBuildings
# PC2   0.1687298 0.2074362      0.2515409    0.1465187         -0.1197172
#     LocationsCaverns LocationsPlayerOwned LocationsWorldMap Bodymodels
# PC2       -0.1025352           -0.1131424        -0.1117231  0.1313985
#     Facemodels      Hair Newmodels Newtextures Forfemalecharacters
# PC2   0.109362 0.1096288 0.1019902   0.1227763            0.303957
#     Formalecharacters  Replacer ECHGECBodybase RobertFemaleBodybase
# PC2         0.1691559 0.1116647      0.3224551            0.1558451
#     RobertMaleBodybase TFFUFFBodybase
# PC2          0.2053913      0.1366896
#           Udl      Pop1     Pop10 ArmorShields   Clothing ClothingFemale
# PC3 0.3107249 0.3042774 0.2085297   -0.1564639 -0.1169796     -0.1172374
#     ClothingMale NPCVendors    Weapons AnimationModified AnimationNew
# PC3    -0.124878 -0.1224503 -0.1430134         0.1751608    0.1747735
#     AudioSoundFX AudioVoices Bodymodels EnvironmentOther EnvironmentSky
# PC3    0.1577999   0.1186242  0.1222878        0.2029478      0.2483777
#     EnvironmentWater EnvironmentWeather Facemodels      Hair  Lighting
# PC3        0.1984152          0.2576377  0.1584171 0.1706883 0.1601322
#     RacesModified     Video Compilation Forfemalecharacters Formalecharacters
# PC3     0.1288883 0.1230099   0.1292663          -0.1448641        -0.1728286
#     GameplayEffectsChanges PerformanceOptimization     Poses  Replacer
# PC3              0.1266725               0.1015748 0.1226477 0.1116089

# %%
modl <- glm(Pop1 ~  ...,family=binomial,data=data);
summary(modl);
# Out:
# Call:
# glm(formula = Pop1 ~ LoreFriendly + Nudity + ArmorShields + AnimationModified +
#     AnimationNew + EnvironmentOther + Facemodels + Hair + Newmodels +
#     Newtextures + Video + Compilation + GameplayEffectsChanges +
#     PerformanceOptimization + Replacer + Anime + NotLoreFriendly +
#     NotSafeForWork + SexySkimpy + Books + Clothing + LocationsBuildings +
#     LocationsWorldMap + NPCs + PlantsFoliage + Weapons + AudioSoundFX +
#     EnvironmentWeather + GuildsFactions + Quests + Companions +
#     Forfemalecharacters + Formalecharacters + Poses + Cheating +
#     Unbalanced + ECHGECBodybase, family = binomial, data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0265  -0.1013  -0.0912  -0.0912   3.5186
#
# Coefficients:
#                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)              -5.47953    0.09757 -56.158  < 2e-16 ***
# LoreFriendly              0.84727    0.17321   4.891 1.00e-06 ***
# Nudity                    1.77617    0.29762   5.968 2.40e-09 ***
# ArmorShields              0.38635    0.32491   1.189 0.234397
# AnimationModified         1.37369    0.36397   3.774 0.000160 ***
# AnimationNew              1.06783    0.34833   3.066 0.002172 **
# EnvironmentOther          0.90168    0.29922   3.013 0.002583 **
# Facemodels                1.27956    0.33532   3.816 0.000136 ***
# Hair                      0.71039    0.38186   1.860 0.062836 .
# Newmodels                 0.14160    0.21285   0.665 0.505870
# Newtextures               0.83413    0.19263   4.330 1.49e-05 ***
# Video                    -2.48529    0.88736  -2.801 0.005098 **
# Compilation               1.98058    0.26891   7.365 1.77e-13 ***
# GameplayEffectsChanges    0.84271    0.19453   4.332 1.48e-05 ***
# PerformanceOptimization   1.84103    0.31468   5.850 4.90e-09 ***
# Replacer                  1.05620    0.19424   5.438 5.40e-08 ***
# Anime                    -0.08318    0.85397  -0.097 0.922410
# NotLoreFriendly           0.30467    0.56668   0.538 0.590827
# NotSafeForWork            1.16754    0.75297   1.551 0.121002
# SexySkimpy                0.18050    0.46763   0.386 0.699499
# Books                     0.27174    0.35806   0.759 0.447905
# Clothing                 -0.36859    0.28436  -1.296 0.194899
# LocationsBuildings       -0.40935    0.33882  -1.208 0.226985
# LocationsWorldMap         0.30249    0.33897   0.892 0.372191
# NPCs                     -0.29941    0.28738  -1.042 0.297473
# PlantsFoliage             0.60400    0.36372   1.661 0.096795 .
# Weapons                  -0.06299    0.24530  -0.257 0.797337
# AudioSoundFX              0.70969    0.35166   2.018 0.043578 *
# EnvironmentWeather        0.62261    0.48767   1.277 0.201706
# GuildsFactions           -0.42735    0.47067  -0.908 0.363897
# Quests                    0.71154    0.30759   2.313 0.020706 *
# Companions               -0.33616    0.38092  -0.883 0.377502
# Forfemalecharacters       0.09403    0.28476   0.330 0.741229
# Formalecharacters        -0.08825    0.33980  -0.260 0.795097
# Poses                     0.19069    0.66837   0.285 0.775410
# Cheating                 -1.12620    1.01222  -1.113 0.265879
# Unbalanced              -22.25548  356.93416  -0.062 0.950283
# ECHGECBodybase            0.46799    0.29140   1.606 0.108267
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 2944.1  on 26220  degrees of freedom
# Residual deviance: 2350.4  on 26183  degrees of freedom
# AIC: 2426.4
#
# Number of Fisher Scoring iterations: 12

# %%
modl2 <- glm(Pop10 ~ ...,family=binomial,data=data);
summary(modl2);
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurred
# Call:
# glm(formula = Pop10 ~ LoreFriendly + Nudity + ArmorShields +
#     AnimationModified + AnimationNew + EnvironmentOther + Facemodels +
#     Hair + Newmodels + Newtextures + Video + Compilation + GameplayEffectsChanges +
#     PerformanceOptimization + Replacer + Anime + NotLoreFriendly +
#     NotSafeForWork + SexySkimpy + Books + Clothing + LocationsBuildings +
#     LocationsWorldMap + NPCs + PlantsFoliage + Weapons + AudioSoundFX +
#     EnvironmentWeather + GuildsFactions + Quests + Companions +
#     Forfemalecharacters + Formalecharacters + Poses + Cheating +
#     Unbalanced + ECHGECBodybase, family = binomial, data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -3.2306  -0.3841  -0.3553  -0.3553   2.8640
#
# Coefficients:
#                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)             -2.731e+00  2.847e-02 -95.950  < 2e-16 ***
# LoreFriendly             2.369e-01  7.633e-02   3.103 0.001913 **
# Nudity                   1.635e+00  1.561e-01  10.478  < 2e-16 ***
# ArmorShields            -3.517e-01  1.352e-01  -2.602 0.009271 **
# AnimationModified        9.822e-01  2.108e-01   4.658 3.19e-06 ***
# AnimationNew             1.209e+00  1.803e-01   6.708 1.97e-11 ***
# EnvironmentOther         9.122e-01  1.482e-01   6.156 7.46e-10 ***
# Facemodels               2.875e-01  1.841e-01   1.562 0.118333
# Hair                     1.127e+00  1.921e-01   5.867 4.45e-09 ***
# Newmodels                2.600e-01  8.655e-02   3.004 0.002666 **
# Newtextures              6.283e-01  7.748e-02   8.109 5.10e-16 ***
# Video                   -3.624e-01  3.071e-01  -1.180 0.238003
# Compilation              7.341e-01  1.861e-01   3.944 8.00e-05 ***
# GameplayEffectsChanges   6.636e-01  8.286e-02   8.008 1.16e-15 ***
# PerformanceOptimization  6.592e-01  2.061e-01   3.199 0.001380 **
# Replacer                 4.899e-01  9.338e-02   5.247 1.55e-07 ***
# Anime                   -1.676e-01  3.167e-01  -0.529 0.596523
# NotLoreFriendly         -5.307e-01  2.142e-01  -2.478 0.013209 *
# NotSafeForWork           1.042e-01  4.244e-01   0.246 0.806026
# SexySkimpy               6.537e-01  1.722e-01   3.796 0.000147 ***
# Books                   -8.160e-03  1.533e-01  -0.053 0.957554
# Clothing                 2.831e-01  9.474e-02   2.989 0.002803 **
# LocationsBuildings      -9.351e-02  1.221e-01  -0.766 0.443855
# LocationsWorldMap        1.617e-01  1.408e-01   1.148 0.250887
# NPCs                     3.519e-01  1.012e-01   3.478 0.000506 ***
# PlantsFoliage            3.618e-01  1.827e-01   1.980 0.047685 *
# Weapons                  2.426e-01  8.572e-02   2.830 0.004651 **
# AudioSoundFX             2.598e-01  2.035e-01   1.277 0.201650
# EnvironmentWeather      -5.904e-01  3.139e-01  -1.881 0.060001 .
# GuildsFactions           4.353e-01  1.790e-01   2.431 0.015038 *
# Quests                   5.731e-01  1.229e-01   4.663 3.11e-06 ***
# Companions               4.861e-01  1.110e-01   4.380 1.19e-05 ***
# Forfemalecharacters      5.407e-01  9.508e-02   5.686 1.30e-08 ***
# Formalecharacters       -3.474e-01  1.231e-01  -2.824 0.004750 **
# Poses                    1.591e+00  3.490e-01   4.559 5.14e-06 ***
# Cheating                -7.628e-01  2.603e-01  -2.931 0.003381 **
# Unbalanced              -3.282e+01  2.886e+04  -0.001 0.999093
# ECHGECBodybase           1.352e+00  9.886e-02  13.676  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 17043  on 26220  degrees of freedom
# Residual deviance: 15097  on 26183  degrees of freedom
# AIC: 15173
#
# Number of Fisher Scoring iterations: 7

# %%
anova(modl, test="Chi");
# Out:
# Analysis of Deviance Table
#
# Model: binomial, link: logit
#
# Response: Pop1
#
# Terms added sequentially (first to last)
#
#
#                         Df Deviance Resid. Df Resid. Dev  Pr(>Chi)
# NULL                                    26220     2944.1
# LoreFriendly             1  103.379     26219     2840.7 < 2.2e-16 ***
# Nudity                   1   61.191     26218     2779.5 5.181e-15 ***
# ArmorShields             1   18.581     26217     2760.9 1.628e-05 ***
# AnimationModified        1   64.393     26216     2696.6 1.019e-15 ***
# AnimationNew             1   21.456     26215     2675.1 3.621e-06 ***
# EnvironmentOther         1   42.747     26214     2632.3 6.231e-11 ***
# Facemodels               1   35.550     26213     2596.8 2.485e-09 ***
# Hair                     1    9.446     26212     2587.3  0.002116 **
# Newmodels                1   23.234     26211     2564.1 1.434e-06 ***
# Newtextures              1   33.042     26210     2531.1 9.017e-09 ***
# Video                    1    4.586     26209     2526.5  0.032228 *
# Compilation              1   46.103     26208     2480.4 1.122e-11 ***
# GameplayEffectsChanges   1   27.501     26207     2452.9 1.570e-07 ***
# PerformanceOptimization  1   27.296     26206     2425.6 1.746e-07 ***
# Replacer                 1   26.090     26205     2399.5 3.259e-07 ***
# Anime                    1    0.117     26204     2399.4  0.732850
# NotLoreFriendly          1    0.674     26203     2398.7  0.411815
# NotSafeForWork           1    1.134     26202     2397.6  0.287021
# SexySkimpy               1    0.745     26201     2396.8  0.388029
# Books                    1    0.910     26200     2395.9  0.340246
# Clothing                 1    1.122     26199     2394.8  0.289555
# LocationsBuildings       1    1.241     26198     2393.6  0.265321
# LocationsWorldMap        1    2.151     26197     2391.4  0.142437
# NPCs                     1    0.617     26196     2390.8  0.432074
# PlantsFoliage            1    1.581     26195     2389.2  0.208650
# Weapons                  1    0.188     26194     2389.0  0.664366
# AudioSoundFX             1    4.590     26193     2384.4  0.032153 *
# EnvironmentWeather       1    1.154     26192     2383.3  0.282767
# GuildsFactions           1    0.618     26191     2382.7  0.431614
# Quests                   1    4.577     26190     2378.1  0.032404 *
# Companions               1    1.323     26189     2376.8  0.250027
# Forfemalecharacters      1    0.952     26188     2375.8  0.329241
# Formalecharacters        1    0.554     26187     2375.2  0.456505
# Poses                    1    0.004     26186     2375.2  0.952809
# Cheating                 1    6.814     26185     2368.4  0.009046 **
# Unbalanced               1   15.554     26184     2352.9 8.020e-05 ***
# ECHGECBodybase           1    2.472     26183     2350.4  0.115923
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
anova(modl2, test="Chi");
# Out:
# Analysis of Deviance Table
#
# Model: binomial, link: logit
#
# Response: Pop10
#
# Terms added sequentially (first to last)
#
#
#                         Df Deviance Resid. Df Resid. Dev  Pr(>Chi)
# NULL                                    26220      17043
# LoreFriendly             1  156.923     26219      16886 < 2.2e-16 ***
# Nudity                   1  282.218     26218      16604 < 2.2e-16 ***
# ArmorShields             1   32.110     26217      16572 1.457e-08 ***
# AnimationModified        1  126.826     26216      16445 < 2.2e-16 ***
# AnimationNew             1   78.844     26215      16366 < 2.2e-16 ***
# EnvironmentOther         1   66.280     26214      16300 3.911e-16 ***
# Facemodels               1   49.052     26213      16251 2.493e-12 ***
# Hair                     1   67.098     26212      16184 2.583e-16 ***
# Newmodels                1  177.109     26211      16007 < 2.2e-16 ***
# Newtextures              1  104.383     26210      15902 < 2.2e-16 ***
# Video                    1    0.004     26209      15902 0.9519886
# Compilation              1   31.190     26208      15871 2.340e-08 ***
# GameplayEffectsChanges   1   56.563     26207      15815 5.442e-14 ***
# PerformanceOptimization  1    9.548     26206      15805 0.0020016 **
# Replacer                 1   34.827     26205      15770 3.603e-09 ***
# Anime                    1    5.067     26204      15765 0.0243845 *
# NotLoreFriendly          1    6.381     26203      15759 0.0115344 *
# NotSafeForWork           1    6.248     26202      15752 0.0124304 *
# SexySkimpy               1   97.642     26201      15655 < 2.2e-16 ***
# Books                    1    7.314     26200      15648 0.0068432 **
# Clothing                 1   47.936     26199      15600 4.403e-12 ***
# LocationsBuildings       1    3.815     26198      15596 0.0508093 .
# LocationsWorldMap        1    6.601     26197      15589 0.0101901 *
# NPCs                     1   38.297     26196      15551 6.075e-10 ***
# PlantsFoliage            1    1.771     26195      15549 0.1832658
# Weapons                  1    3.004     26194      15546 0.0830575 .
# AudioSoundFX             1    1.799     26193      15544 0.1797880
# EnvironmentWeather       1    3.323     26192      15541 0.0682967 .
# GuildsFactions           1   11.370     26191      15530 0.0007466 ***
# Quests                   1   19.491     26190      15510 1.011e-05 ***
# Companions               1   18.582     26189      15492 1.627e-05 ***
# Forfemalecharacters      1  111.528     26188      15380 < 2.2e-16 ***
# Formalecharacters        1   40.312     26187      15340 2.165e-10 ***
# Poses                    1   15.284     26186      15324 9.249e-05 ***
# Cheating                 1   17.449     26185      15307 2.950e-05 ***
# Unbalanced               1   34.515     26184      15272 4.231e-09 ***
# ECHGECBodybase           1  175.551     26183      15097 < 2.2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
drop1(modl, test="Chi");
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurred
# Single term deletions
#
# Model:
# Pop1 ~ LoreFriendly + Nudity + ArmorShields + AnimationModified +
#     AnimationNew + EnvironmentOther + Facemodels + Hair + Newmodels +
#     Newtextures + Video + Compilation + GameplayEffectsChanges +
#     PerformanceOptimization + Replacer + Anime + NotLoreFriendly +
#     NotSafeForWork + SexySkimpy + Books + Clothing + LocationsBuildings +
#     LocationsWorldMap + NPCs + PlantsFoliage + Weapons + AudioSoundFX +
#     EnvironmentWeather + GuildsFactions + Quests + Companions +
#     Forfemalecharacters + Formalecharacters + Poses + Cheating +
#     Unbalanced + ECHGECBodybase
#                         Df Deviance    AIC    LRT  Pr(>Chi)
# <none>                       2350.4 2426.4
# LoreFriendly             1   2372.0 2446.0 21.615 3.332e-06 ***
# Nudity                   1   2377.6 2451.6 27.153 1.880e-07 ***
# ArmorShields             1   2351.8 2425.8  1.365 0.2426082
# AnimationModified        1   2362.8 2436.8 12.431 0.0004223 ***
# AnimationNew             1   2358.8 2432.8  8.419 0.0037130 **
# EnvironmentOther         1   2358.5 2432.5  8.121 0.0043744 **
# Facemodels               1   2362.6 2436.6 12.233 0.0004694 ***
# Hair                     1   2353.6 2427.6  3.216 0.0729201 .
# Newmodels                1   2350.8 2424.8  0.440 0.5072742
# Newtextures              1   2368.3 2442.3 17.867 2.369e-05 ***
# Video                    1   2361.3 2435.3 10.883 0.0009707 ***
# Compilation              1   2393.7 2467.7 43.261 4.790e-11 ***
# GameplayEffectsChanges   1   2367.0 2441.0 16.635 4.531e-05 ***
# PerformanceOptimization  1   2375.9 2449.9 25.474 4.483e-07 ***
# Replacer                 1   2376.2 2450.2 25.813 3.761e-07 ***
# Anime                    1   2350.4 2424.4  0.010 0.9218216
# NotLoreFriendly          1   2350.7 2424.7  0.275 0.6001783
# NotSafeForWork           1   2352.5 2426.5  2.091 0.1481250
# SexySkimpy               1   2350.6 2424.6  0.146 0.7026301
# Books                    1   2351.0 2425.0  0.555 0.4561191
# Clothing                 1   2352.2 2426.2  1.768 0.1835782
# LocationsBuildings       1   2351.9 2425.9  1.541 0.2144722
# LocationsWorldMap        1   2351.2 2425.2  0.772 0.3794880
# NPCs                     1   2351.5 2425.5  1.126 0.2886135
# PlantsFoliage            1   2353.0 2427.0  2.563 0.1093933
# Weapons                  1   2350.5 2424.5  0.067 0.7964644
# AudioSoundFX             1   2354.1 2428.1  3.728 0.0535094 .
# EnvironmentWeather       1   2351.9 2425.9  1.521 0.2174038
# GuildsFactions           1   2351.3 2425.3  0.861 0.3535074
# Quests                   1   2355.3 2429.3  4.858 0.0275131 *
# Companions               1   2351.2 2425.2  0.836 0.3606725
# Forfemalecharacters      1   2350.5 2424.5  0.109 0.7417169
# Formalecharacters        1   2350.5 2424.5  0.068 0.7944382
# Poses                    1   2350.5 2424.5  0.080 0.7775330
# Cheating                 1   2352.2 2426.2  1.818 0.1775670
# Unbalanced               1   2366.0 2440.0 15.584 7.892e-05 ***
# ECHGECBodybase           1   2352.9 2426.9  2.472 0.1159227
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
drop1(modl2, test="Chi");
# Out:
# Warning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurredWarning message:
# : glm.fit: fitted probabilities numerically 0 or 1 occurred
# Single term deletions
#
# Model:
# Pop10 ~ LoreFriendly + Nudity + ArmorShields + AnimationModified +
#     AnimationNew + EnvironmentOther + Facemodels + Hair + Newmodels +
#     Newtextures + Video + Compilation + GameplayEffectsChanges +
#     PerformanceOptimization + Replacer + Anime + NotLoreFriendly +
#     NotSafeForWork + SexySkimpy + Books + Clothing + LocationsBuildings +
#     LocationsWorldMap + NPCs + PlantsFoliage + Weapons + AudioSoundFX +
#     EnvironmentWeather + GuildsFactions + Quests + Companions +
#     Forfemalecharacters + Formalecharacters + Poses + Cheating +
#     Unbalanced + ECHGECBodybase
#                         Df Deviance   AIC     LRT  Pr(>Chi)
# <none>                        15097 15173
# LoreFriendly             1    15106 15180   9.345 0.0022362 **
# Nudity                   1    15201 15275 104.448 < 2.2e-16 ***
# ArmorShields             1    15104 15178   6.987 0.0082094 **
# AnimationModified        1    15118 15192  20.650 5.513e-06 ***
# AnimationNew             1    15138 15212  41.399 1.241e-10 ***
# EnvironmentOther         1    15131 15205  34.341 4.626e-09 ***
# Facemodels               1    15099 15173   2.351 0.1251719
# Hair                     1    15129 15203  31.834 1.680e-08 ***
# Newmodels                1    15106 15180   8.916 0.0028274 **
# Newtextures              1    15160 15234  63.116 1.949e-15 ***
# Video                    1    15098 15172   1.479 0.2239858
# Compilation              1    15112 15186  14.657 0.0001289 ***
# GameplayEffectsChanges   1    15155 15229  58.066 2.535e-14 ***
# PerformanceOptimization  1    15106 15180   9.315 0.0022729 **
# Replacer                 1    15123 15197  25.961 3.483e-07 ***
# Anime                    1    15097 15171   0.284 0.5938694
# NotLoreFriendly          1    15103 15177   6.500 0.0107846 *
# NotSafeForWork           1    15097 15171   0.060 0.8061328
# SexySkimpy               1    15111 15185  14.054 0.0001777 ***
# Books                    1    15097 15171   0.003 0.9575316
# Clothing                 1    15106 15180   8.673 0.0032292 **
# LocationsBuildings       1    15098 15172   0.593 0.4412547
# LocationsWorldMap        1    15098 15172   1.297 0.2548108
# NPCs                     1    15109 15183  11.675 0.0006334 ***
# PlantsFoliage            1    15101 15175   3.776 0.0520072 .
# Weapons                  1    15105 15179   7.794 0.0052407 **
# AudioSoundFX             1    15098 15172   1.592 0.2069896
# EnvironmentWeather       1    15101 15175   3.762 0.0524348 .
# GuildsFactions           1    15103 15177   5.689 0.0170728 *
# Quests                   1    15117 15191  20.443 6.144e-06 ***
# Companions               1    15115 15189  17.854 2.386e-05 ***
# Forfemalecharacters      1    15128 15202  31.399 2.101e-08 ***
# Formalecharacters        1    15105 15179   8.173 0.0042527 **
# Poses                    1    15116 15190  19.022 1.292e-05 ***
# Cheating                 1    15108 15182  10.717 0.0010618 **
# Unbalanced               1    15132 15206  35.061 3.195e-09 ***
# ECHGECBodybase           1    15272 15346 175.551 < 2.2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
