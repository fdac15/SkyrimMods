# %%
f = read.csv("fit_data.csv");

# %%
vars = cbind(f$Mod, f$Udl, f$Pop1, f$Pop10, f$Anime,f$LoreFriendly,f$NotLoreFriendly,f$NotSafeForWork,f$Nudity,f$SexySkimpy,f$Unrealistic,f$ArmorShields,f$Books,f$Clothing,f$ClothingFemale,f$ClothingMale,f$Creatures,f$CreaturesRideable,f$ItemsApparatus,f$ItemsClutter,f$ItemsFurniture,f$ItemsIngredients,f$ItemsLeveled,f$LocationsBuildings,f$LocationsCaverns,f$LocationsDungeons,f$LocationsPlayerOwned,f$LocationsWorldMap,f$MagicEnchantments,f$MagicPotions,f$MagicSpells,f$NPCTrainers,f$NPCVendors,f$NPCs,f$PlantsFoliage,f$Weapons,f$AnimationModified,f$AnimationNew,f$AudioSoundFX,f$AudioVoices,f$Birthsigns,f$Bodymodels,f$Classescomponent,f$EnvironmentOther,f$EnvironmentSky,f$EnvironmentWater,f$EnvironmentWeather,f$Facemodels,f$GuildsFactions,f$Hair,f$LeveledLists,f$Lighting,f$NewLands,f$Newmodels,f$Newtextures,f$Quests,f$RacesModified,f$ScriptedEvents,f$Video,f$Chargen,f$CompanionFriendly,f$Companions,f$Compilation,f$ENBPreset,f$Forfemalecharacters,f$Formalecharacters,f$GameplayEffectsChanges,f$Official,f$PerformanceOptimization,f$Poses,f$Relatedtohorses,f$RelatedtoMoviesTVOtherGames,f$Relatedtovampires,f$Replacer,f$Solstheim,f$none);
colf = c("Mod", "Udl", "Pop1", "Pop10", "Anime","LoreFriendly","NotLoreFriendly","NotSafeForWork","Nudity","SexySkimpy","Unrealistic","ArmorShields","Books","Clothing","ClothingFemale","ClothingMale","Creatures","CreaturesRideable","ItemsApparatus","ItemsClutter","ItemsFurniture","ItemsIngredients","ItemsLeveled","LocationsBuildings","LocationsCaverns","LocationsDungeons","LocationsPlayerOwned","LocationsWorldMap","MagicEnchantments","MagicPotions","MagicSpells","NPCTrainers","NPCVendors","NPCs","PlantsFoliage","Weapons","AnimationModified","AnimationNew","AudioSoundFX","AudioVoices","Birthsigns","Bodymodels","Classescomponent","EnvironmentOther","EnvironmentSky","EnvironmentWater","EnvironmentWeather","Facemodels","GuildsFactions","Hair","LeveledLists","Lighting","NewLands","Newmodels","Newtextures","Quests","RacesModified","ScriptedEvents","Video","Chargen","CompanionFriendly","Companions","Compilation","ENBPreset","Forfemalecharacters","Formalecharacters","GameplayEffectsChanges","Official","PerformanceOptimization","Poses","Relatedtohorses","RelatedtoMoviesTVOtherGames","Relatedtovampires","Replacer","Solstheim","none");

dimnames(vars)[[2]] <- colf
data <- data.frame(vars);

# %%
summary(data);
# Out:
#       Mod             Udl               Pop1             Pop10
#  Min.   :    8   Min.   :      0   Min.   :0.00000   Min.   :0.0
#  1st Qu.:16208   1st Qu.:    241   1st Qu.:0.00000   1st Qu.:0.0
#  Median :31784   Median :    733   Median :0.00000   Median :0.0
#  Mean   :34239   Mean   :  10818   Mean   :0.01002   Mean   :0.1
#  3rd Qu.:54016   3rd Qu.:   2813   3rd Qu.:0.00000   3rd Qu.:0.0
#  Max.   :70742   Max.   :8224648   Max.   :1.00000   Max.   :1.0
#      Anime          LoreFriendly    NotLoreFriendly   NotSafeForWork
#  Min.   :0.00000   Min.   :0.0000   Min.   :0.00000   Min.   :0.000000
#  1st Qu.:0.00000   1st Qu.:0.0000   1st Qu.:0.00000   1st Qu.:0.000000
#  Median :0.00000   Median :0.0000   Median :0.00000   Median :0.000000
#  Mean   :0.01799   Mean   :0.2167   Mean   :0.05159   Mean   :0.007147
#  3rd Qu.:0.00000   3rd Qu.:0.0000   3rd Qu.:0.00000   3rd Qu.:0.000000
#  Max.   :1.00000   Max.   :1.0000   Max.   :1.00000   Max.   :1.000000
#      Nudity          SexySkimpy       Unrealistic       ArmorShields
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.00000
#  Mean   :0.00843   Mean   :0.03186   Mean   :0.02579   Mean   :0.04092
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#      Books            Clothing       ClothingFemale     ClothingMale
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.00000
#  Mean   :0.02627   Mean   :0.04479   Mean   :0.03593   Mean   :0.02637
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#    Creatures       CreaturesRideable ItemsApparatus    ItemsClutter
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.0000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.0000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.0000   Median :0.00000
#  Mean   :0.02776   Mean   :0.00692   Mean   :0.0113   Mean   :0.03093
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.0000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.0000   Max.   :1.00000
#  ItemsFurniture    ItemsIngredients   ItemsLeveled     LocationsBuildings
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.00000
#  Mean   :0.01777   Mean   :0.01882   Mean   :0.01243   Mean   :0.04258
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#  LocationsCaverns LocationsDungeons LocationsPlayerOwned LocationsWorldMap
#  Min.   :0.0000   Min.   :0.00000   Min.   :0.00000      Min.   :0.00000
#  1st Qu.:0.0000   1st Qu.:0.00000   1st Qu.:0.00000      1st Qu.:0.00000
#  Median :0.0000   Median :0.00000   Median :0.00000      Median :0.00000
#  Mean   :0.0111   Mean   :0.01922   Mean   :0.04909      Mean   :0.02914
#  3rd Qu.:0.0000   3rd Qu.:0.00000   3rd Qu.:0.00000      3rd Qu.:0.00000
#  Max.   :1.0000   Max.   :1.00000   Max.   :1.00000      Max.   :1.00000
#  MagicEnchantments  MagicPotions      MagicSpells       NPCTrainers
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.000000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.000000
#  Mean   :0.02544   Mean   :0.01449   Mean   :0.05068   Mean   :0.006618
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.000000
#    NPCVendors           NPCs         PlantsFoliage        Weapons
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.00000
#  Mean   :0.02448   Mean   :0.08098   Mean   :0.01137   Mean   :0.09165
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#  AnimationModified   AnimationNew       AudioSoundFX      AudioVoices
#  Min.   :0.000000   Min.   :0.000000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.000000   Median :0.000000   Median :0.00000   Median :0.00000
#  Mean   :0.009159   Mean   :0.006769   Mean   :0.01477   Mean   :0.01238
#  3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.000000   Max.   :1.000000   Max.   :1.00000   Max.   :1.00000
#    Birthsigns         Bodymodels      Classescomponent   EnvironmentOther
#  Min.   :0.000000   Min.   :0.00000   Min.   :0.000000   Min.   :0.0000
#  1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.0000
#  Median :0.000000   Median :0.00000   Median :0.000000   Median :0.0000
#  Mean   :0.001485   Mean   :0.01266   Mean   :0.004253   Mean   :0.0308
#  3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.0000
#  Max.   :1.000000   Max.   :1.00000   Max.   :1.000000   Max.   :1.0000
#  EnvironmentSky    EnvironmentWater   EnvironmentWeather   Facemodels
#  Min.   :0.00000   Min.   :0.000000   Min.   :0.000000   Min.   :0.0000
#  1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.0000
#  Median :0.00000   Median :0.000000   Median :0.000000   Median :0.0000
#  Mean   :0.01095   Mean   :0.007574   Mean   :0.008606   Mean   :0.0194
#  3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.0000
#  Max.   :1.00000   Max.   :1.000000   Max.   :1.000000   Max.   :1.0000
#  GuildsFactions         Hair          LeveledLists        Lighting
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.00000
#  Mean   :0.01439   Mean   :0.01002   Mean   :0.01296   Mean   :0.01907
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#     NewLands         Newmodels        Newtextures         Quests
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.0000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.0000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.0000   Median :0.00000
#  Mean   :0.01158   Mean   :0.05687   Mean   :0.1133   Mean   :0.02121
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.0000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.0000   Max.   :1.00000
#  RacesModified     ScriptedEvents        Video             Chargen
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.000000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.000000   Median :0.00000
#  Mean   :0.01495   Mean   :0.01895   Mean   :0.006366   Mean   :0.01422
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000   3rd Qu.:0.00000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.000000   Max.   :1.00000
#  CompanionFriendly   Companions       Compilation        ENBPreset
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.000000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.000000
#  Mean   :0.08412   Mean   :0.06963   Mean   :0.01022   Mean   :0.001912
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.000000
#  Forfemalecharacters Formalecharacters GameplayEffectsChanges    Official
#  Min.   :0.0000      Min.   :0.00000   Min.   :0.00000        Min.   :0.00000
#  1st Qu.:0.0000      1st Qu.:0.00000   1st Qu.:0.00000        1st Qu.:0.00000
#  Median :0.0000      Median :0.00000   Median :0.00000        Median :0.00000
#  Mean   :0.1134      Mean   :0.08988   Mean   :0.09331        Mean   :0.00614
#  3rd Qu.:0.0000      3rd Qu.:0.00000   3rd Qu.:0.00000        3rd Qu.:0.00000
#  Max.   :1.0000      Max.   :1.00000   Max.   :1.00000        Max.   :1.00000
#  PerformanceOptimization     Poses         Relatedtohorses
#  Min.   :0.0000          Min.   :0.00000   Min.   :0.000000
#  1st Qu.:0.0000          1st Qu.:0.00000   1st Qu.:0.000000
#  Median :0.0000          Median :0.00000   Median :0.000000
#  Mean   :0.0152          Mean   :0.00307   Mean   :0.009537
#  3rd Qu.:0.0000          3rd Qu.:0.00000   3rd Qu.:0.000000
#  Max.   :1.0000          Max.   :1.00000   Max.   :1.000000
#  RelatedtoMoviesTVOtherGames Relatedtovampires    Replacer
#  Min.   :0.00000             Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000             1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000             Median :0.00000   Median :0.00000
#  Mean   :0.02559             Mean   :0.01709   Mean   :0.08216
#  3rd Qu.:0.00000             3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1.00000             Max.   :1.00000   Max.   :1.00000
#    Solstheim             none
#  Min.   :0.000000   Min.   :0.0000
#  1st Qu.:0.000000   1st Qu.:0.0000
#  Median :0.000000   Median :0.0000
#  Mean   :0.006442   Mean   :0.2769
#  3rd Qu.:0.000000   3rd Qu.:1.0000
#  Max.   :1.000000   Max.   :1.0000

# %%
# Define a function
hiCor <- function(x, level){
  res <- cor(x,method="spearman");
  res1 <- res; res1[res<0] <- -res[res < 0];
  for (i in 1:dim(x)[2]){
    res1[i,i] <- 0;
  }
  sel <- apply(res1,1,max) > level;
  res[sel,sel];
}
hiCor(data,.6)
# Out:
#                      Clothing ClothingFemale ClothingMale Forfemalecharacters
# Clothing            1.0000000      0.6144248    0.5884346           0.2376087
# ClothingFemale      0.6144248      1.0000000    0.6170572           0.3326770
# ClothingMale        0.5884346      0.6170572    1.0000000           0.2125977
# Forfemalecharacters 0.2376087      0.3326770    0.2125977           1.0000000
# Formalecharacters   0.2211797      0.1889092    0.3155996           0.6510534
#                     Formalecharacters
# Clothing                    0.2211797
# ClothingFemale              0.1889092
# ClothingMale                0.3155996
# Forfemalecharacters         0.6510534
# Formalecharacters           1.0000000

# %%
res<-prcomp(vars, retx=F,scale=T)$rotation[,1:3];
resAbs <- res;
resAbs[res<0] <- -res[res<0];
for (i in 1:3)
  print(t(res[resAbs[,i]>.3,i,drop=FALSE]));
# Out:
#
# PC1
#     Forfemalecharacters
# PC2           0.3409836
#     EnvironmentSky EnvironmentWater EnvironmentWeather
# PC3      0.3491238        0.3006301          0.3476418

# %%
modl <- glm(Pop1 ~ ...,family=binomial,data=data);
summary(modl);
# Out:
# Call:
# glm(formula = Pop1 ~ Anime + LoreFriendly + NotLoreFriendly +
#     NotSafeForWork + Nudity + SexySkimpy + Unrealistic + ArmorShields +
#     Books + Clothing + ClothingFemale + ClothingMale + Creatures +
#     CreaturesRideable + ItemsApparatus + ItemsClutter + ItemsFurniture +
#     ItemsIngredients + ItemsLeveled + LocationsBuildings + LocationsCaverns +
#     LocationsDungeons + LocationsPlayerOwned + LocationsWorldMap +
#     MagicEnchantments + MagicPotions + MagicSpells + NPCTrainers +
#     NPCVendors + NPCs + PlantsFoliage + Weapons + AnimationModified +
#     AnimationNew + AudioSoundFX + AudioVoices + Birthsigns +
#     Bodymodels + Classescomponent + EnvironmentOther + EnvironmentSky +
#     EnvironmentWater + EnvironmentWeather + Facemodels + GuildsFactions +
#     Hair + LeveledLists + Lighting + NewLands + Newmodels + Newtextures +
#     Quests + RacesModified + ScriptedEvents + Video + Chargen +
#     CompanionFriendly + Companions + Compilation + ENBPreset +
#     Forfemalecharacters + Formalecharacters + GameplayEffectsChanges +
#     Official + PerformanceOptimization + Poses + Relatedtohorses +
#     RelatedtoMoviesTVOtherGames + Relatedtovampires + Replacer +
#     Solstheim + none, family = binomial, data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.5628  -0.1219  -0.0715  -0.0191   4.1504
#
# Coefficients:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 -5.968668   0.120953 -49.347  < 2e-16 ***
# Anime                        0.739238   0.299911   2.465 0.013707 *
# LoreFriendly                 1.139844   0.119631   9.528  < 2e-16 ***
# NotLoreFriendly              0.243948   0.242391   1.006 0.314211
# NotSafeForWork               0.662709   0.429721   1.542 0.123029
# Nudity                      -0.653868   0.569587  -1.148 0.250981
# SexySkimpy                   0.610045   0.253424   2.407 0.016075 *
# Unrealistic                  0.387629   0.273365   1.418 0.156195
# ArmorShields                 0.433731   0.213340   2.033 0.042048 *
# Books                       -0.390384   0.316984  -1.232 0.218115
# Clothing                     0.246722   0.266278   0.927 0.354155
# ClothingFemale              -0.032228   0.315919  -0.102 0.918747
# ClothingMale                -0.269625   0.360754  -0.747 0.454826
# Creatures                    0.182087   0.231980   0.785 0.432498
# CreaturesRideable            0.190465   0.511839   0.372 0.709803
# ItemsApparatus              -0.147403   0.394154  -0.374 0.708424
# ItemsClutter                -0.513321   0.281772  -1.822 0.068491 .
# ItemsFurniture              -1.011531   0.407808  -2.480 0.013123 *
# ItemsIngredients             0.226347   0.308652   0.733 0.463352
# ItemsLeveled                 0.009657   0.333012   0.029 0.976866
# LocationsBuildings          -0.112712   0.262595  -0.429 0.667760
# LocationsCaverns             0.657981   0.392579   1.676 0.093729 .
# LocationsDungeons           -0.770719   0.372197  -2.071 0.038384 *
# LocationsPlayerOwned        -0.462630   0.294183  -1.573 0.115813
# LocationsWorldMap            0.500857   0.260604   1.922 0.054617 .
# MagicEnchantments           -0.430499   0.315954  -1.363 0.173029
# MagicPotions                -0.223983   0.381495  -0.587 0.557124
# MagicSpells                  0.118883   0.223071   0.533 0.594077
# NPCTrainers                 -0.541393   0.508036  -1.066 0.286578
# NPCVendors                   0.609754   0.264070   2.309 0.020940 *
# NPCs                        -0.102016   0.187936  -0.543 0.587252
# PlantsFoliage                0.594183   0.290460   2.046 0.040790 *
# Weapons                     -0.213442   0.180250  -1.184 0.236357
# AnimationModified            1.334424   0.267230   4.994 5.93e-07 ***
# AnimationNew                 0.946929   0.299158   3.165 0.001549 **
# AudioSoundFX                 0.126228   0.284951   0.443 0.657780
# AudioVoices                  0.725728   0.299187   2.426 0.015280 *
# Birthsigns                  -2.239594   1.120059  -2.000 0.045551 *
# Bodymodels                  -0.676582   0.318826  -2.122 0.033829 *
# Classescomponent            -1.437219   0.662414  -2.170 0.030032 *
# EnvironmentOther             0.872309   0.194434   4.486 7.24e-06 ***
# EnvironmentSky              -0.880283   0.403885  -2.180 0.029291 *
# EnvironmentWater            -0.295389   0.369516  -0.799 0.424061
# EnvironmentWeather           1.237295   0.380060   3.256 0.001132 **
# Facemodels                   0.481849   0.253588   1.900 0.057417 .
# GuildsFactions               0.204850   0.305798   0.670 0.502931
# Hair                         0.671652   0.291932   2.301 0.021408 *
# LeveledLists                 0.854608   0.266320   3.209 0.001332 **
# Lighting                    -0.222821   0.308571  -0.722 0.470228
# NewLands                    -0.275307   0.405805  -0.678 0.497505
# Newmodels                    0.402504   0.162096   2.483 0.013024 *
# Newtextures                  0.882076   0.138638   6.362 1.99e-10 ***
# Quests                       0.319525   0.295264   1.082 0.279179
# RacesModified               -0.447258   0.315661  -1.417 0.156514
# ScriptedEvents               0.693373   0.227477   3.048 0.002303 **
# Video                       -0.149869   0.402704  -0.372 0.709776
# Chargen                      1.455301   0.219302   6.636 3.22e-11 ***
# CompanionFriendly            0.227126   0.158579   1.432 0.152071
# Companions                  -0.405512   0.236800  -1.712 0.086811 .
# Compilation                  0.237728   0.279993   0.849 0.395853
# ENBPreset                    2.258623   0.472700   4.778 1.77e-06 ***
# Forfemalecharacters          0.237596   0.210353   1.130 0.258681
# Formalecharacters           -0.508056   0.240401  -2.113 0.034569 *
# GameplayEffectsChanges       1.014418   0.135927   7.463 8.46e-14 ***
# Official                    -2.255222   0.603642  -3.736 0.000187 ***
# PerformanceOptimization      1.428215   0.191399   7.462 8.52e-14 ***
# Poses                        0.210493   0.424424   0.496 0.619930
# Relatedtohorses             -0.084929   0.449447  -0.189 0.850122
# RelatedtoMoviesTVOtherGames -0.731022   0.339314  -2.154 0.031208 *
# Relatedtovampires            0.089500   0.290541   0.308 0.758048
# Replacer                     0.943584   0.131966   7.150 8.67e-13 ***
# Solstheim                    0.210424   0.392216   0.537 0.591612
# none                        -2.644108   0.717432  -3.686 0.000228 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 4456.5  on 39739  degrees of freedom
# Residual deviance: 3299.9  on 39667  degrees of freedom
# AIC: 3445.9
#
# Number of Fisher Scoring iterations: 11

# %%
modl2 <- glm(Pop10 ~ ...,family=binomial,data=data);
summary(modl2);
# Out:
# Call:
# glm(formula = Pop10 ~ Anime + LoreFriendly + NotLoreFriendly +
#     NotSafeForWork + Nudity + SexySkimpy + Unrealistic + ArmorShields +
#     Books + Clothing + ClothingFemale + ClothingMale + Creatures +
#     CreaturesRideable + ItemsApparatus + ItemsClutter + ItemsFurniture +
#     ItemsIngredients + ItemsLeveled + LocationsBuildings + LocationsCaverns +
#     LocationsDungeons + LocationsPlayerOwned + LocationsWorldMap +
#     MagicEnchantments + MagicPotions + MagicSpells + NPCTrainers +
#     NPCVendors + NPCs + PlantsFoliage + Weapons + AnimationModified +
#     AnimationNew + AudioSoundFX + AudioVoices + Birthsigns +
#     Bodymodels + Classescomponent + EnvironmentOther + EnvironmentSky +
#     EnvironmentWater + EnvironmentWeather + Facemodels + GuildsFactions +
#     Hair + LeveledLists + Lighting + NewLands + Newmodels + Newtextures +
#     Quests + RacesModified + ScriptedEvents + Video + Chargen +
#     CompanionFriendly + Companions + Compilation + ENBPreset +
#     Forfemalecharacters + Formalecharacters + GameplayEffectsChanges +
#     Official + PerformanceOptimization + Poses + Relatedtohorses +
#     RelatedtoMoviesTVOtherGames + Relatedtovampires + Replacer +
#     Solstheim + none, family = binomial, data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6541  -0.4591  -0.3612  -0.2590   3.0016
#
# Coefficients:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 -2.697033   0.033660 -80.125  < 2e-16 ***
# Anime                        0.792190   0.100259   7.901 2.76e-15 ***
# LoreFriendly                 0.478344   0.041974  11.396  < 2e-16 ***
# NotLoreFriendly             -0.008482   0.077082  -0.110 0.912379
# NotSafeForWork               0.571363   0.154036   3.709 0.000208 ***
# Nudity                       0.151315   0.157245   0.962 0.335904
# SexySkimpy                   0.885957   0.085329  10.383  < 2e-16 ***
# Unrealistic                  0.569269   0.090666   6.279 3.41e-10 ***
# ArmorShields                 0.011614   0.084370   0.138 0.890508
# Books                       -0.158649   0.114888  -1.381 0.167311
# Clothing                     0.094573   0.095409   0.991 0.321572
# ClothingFemale               0.591605   0.106241   5.569 2.57e-08 ***
# ClothingMale                -0.287370   0.127611  -2.252 0.024327 *
# Creatures                    0.022731   0.097942   0.232 0.816469
# CreaturesRideable            0.277182   0.201358   1.377 0.168646
# ItemsApparatus              -0.018082   0.161816  -0.112 0.911027
# ItemsClutter                -0.122137   0.100044  -1.221 0.222147
# ItemsFurniture              -0.321014   0.140742  -2.281 0.022557 *
# ItemsIngredients            -0.128947   0.136541  -0.944 0.344973
# ItemsLeveled                -0.128152   0.149986  -0.854 0.392868
# LocationsBuildings           0.022423   0.096227   0.233 0.815746
# LocationsCaverns            -0.037825   0.170848  -0.221 0.824785
# LocationsDungeons           -0.074766   0.136330  -0.548 0.583404
# LocationsPlayerOwned        -0.253826   0.096019  -2.644 0.008205 **
# LocationsWorldMap            0.266412   0.105841   2.517 0.011833 *
# MagicEnchantments            0.024956   0.108118   0.231 0.817451
# MagicPotions                -0.343908   0.156753  -2.194 0.028239 *
# MagicSpells                 -0.071162   0.082041  -0.867 0.385724
# NPCTrainers                 -0.650820   0.229963  -2.830 0.004653 **
# NPCVendors                   0.465688   0.107677   4.325 1.53e-05 ***
# NPCs                        -0.094712   0.070240  -1.348 0.177529
# PlantsFoliage                0.326332   0.143713   2.271 0.023164 *
# Weapons                     -0.078720   0.060565  -1.300 0.193685
# AnimationModified            1.259694   0.138571   9.091  < 2e-16 ***
# AnimationNew                 1.031634   0.159177   6.481 9.11e-11 ***
# AudioSoundFX                 0.043646   0.131070   0.333 0.739138
# AudioVoices                  0.073503   0.144698   0.508 0.611472
# Birthsigns                  -2.260326   0.644086  -3.509 0.000449 ***
# Bodymodels                  -0.309861   0.138659  -2.235 0.025438 *
# Classescomponent            -0.585637   0.274369  -2.134 0.032803 *
# EnvironmentOther             0.551036   0.089318   6.169 6.86e-10 ***
# EnvironmentSky              -0.266616   0.176704  -1.509 0.131343
# EnvironmentWater            -0.515005   0.199065  -2.587 0.009678 **
# EnvironmentWeather           0.669631   0.186576   3.589 0.000332 ***
# Facemodels                  -0.177348   0.124805  -1.421 0.155317
# GuildsFactions              -0.122174   0.138239  -0.884 0.376810
# Hair                         0.485986   0.145063   3.350 0.000808 ***
# LeveledLists                 0.404251   0.128918   3.136 0.001714 **
# Lighting                     0.127732   0.124741   1.024 0.305846
# NewLands                    -0.121291   0.160013  -0.758 0.448448
# Newmodels                    0.541583   0.063468   8.533  < 2e-16 ***
# Newtextures                  0.680169   0.051759  13.141  < 2e-16 ***
# Quests                       0.397570   0.113138   3.514 0.000441 ***
# RacesModified               -0.092157   0.130250  -0.708 0.479234
# ScriptedEvents               0.748126   0.099115   7.548 4.42e-14 ***
# Video                       -0.545323   0.204999  -2.660 0.007811 **
# Chargen                      0.556550   0.121447   4.583 4.59e-06 ***
# CompanionFriendly            0.016511   0.063659   0.259 0.795352
# Companions                  -0.067576   0.076876  -0.879 0.379386
# Compilation                  0.235935   0.138538   1.703 0.088562 .
# ENBPreset                    1.065826   0.283525   3.759 0.000170 ***
# Forfemalecharacters          0.104893   0.071285   1.471 0.141169
# Formalecharacters           -0.313408   0.081122  -3.863 0.000112 ***
# GameplayEffectsChanges       0.571047   0.054237  10.529  < 2e-16 ***
# Official                    -1.826437   0.291256  -6.271 3.59e-10 ***
# PerformanceOptimization      0.890472   0.104172   8.548  < 2e-16 ***
# Poses                       -0.447919   0.261131  -1.715 0.086290 .
# Relatedtohorses              0.160046   0.168864   0.948 0.343241
# RelatedtoMoviesTVOtherGames  0.410317   0.089766   4.571 4.85e-06 ***
# Relatedtovampires            0.192948   0.114064   1.692 0.090727 .
# Replacer                     0.342299   0.055546   6.162 7.16e-10 ***
# Solstheim                   -0.208771   0.197669  -1.056 0.290893
# none                        -0.681128   0.063102 -10.794  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 25838  on 39739  degrees of freedom
# Residual deviance: 22718  on 39667  degrees of freedom
# AIC: 22864
#
# Number of Fisher Scoring iterations: 6

# %%
anova(modl, test="Chi");
# Out:
# Analysis of Deviance Table
#
# Model: binomial, link: logit
#
# Response: Pop1
#
# Terms added sequentially (first to last)
#
#
#                             Df Deviance Resid. Df Resid. Dev  Pr(>Chi)
# NULL                                        39739     4456.5
# Anime                        1    13.97     39738     4442.5 0.0001860 ***
# LoreFriendly                 1   342.42     39737     4100.1 < 2.2e-16 ***
# NotLoreFriendly              1    12.95     39736     4087.2 0.0003203 ***
# NotSafeForWork               1     4.57     39735     4082.6 0.0324709 *
# Nudity                       1     0.06     39734     4082.5 0.8014360
# SexySkimpy                   1    13.89     39733     4068.7 0.0001934 ***
# Unrealistic                  1     7.13     39732     4061.5 0.0075812 **
# ArmorShields                 1     7.77     39731     4053.7 0.0053070 **
# Books                        1     0.85     39730     4052.9 0.3560002
# Clothing                     1     0.85     39729     4052.0 0.3574910
# ClothingFemale               1     0.00     39728     4052.0 0.9536892
# ClothingMale                 1     0.74     39727     4051.3 0.3903498
# Creatures                    1    13.41     39726     4037.9 0.0002503 ***
# CreaturesRideable            1     1.76     39725     4036.1 0.1848320
# ItemsApparatus               1     1.78     39724     4034.4 0.1816712
# ItemsClutter                 1     0.01     39723     4034.3 0.9192371
# ItemsFurniture               1     0.38     39722     4034.0 0.5362315
# ItemsIngredients             1     3.27     39721     4030.7 0.0703570 .
# ItemsLeveled                 1     3.68     39720     4027.0 0.0550845 .
# LocationsBuildings           1     0.00     39719     4027.0 0.9874939
# LocationsCaverns             1     4.99     39718     4022.0 0.0255668 *
# LocationsDungeons            1     0.05     39717     4022.0 0.8310791
# LocationsPlayerOwned         1     6.90     39716     4015.1 0.0086133 **
# LocationsWorldMap            1     4.02     39715     4011.1 0.0450256 *
# MagicEnchantments            1     0.01     39714     4011.1 0.9319958
# MagicPotions                 1     0.28     39713     4010.8 0.5955652
# MagicSpells                  1     1.06     39712     4009.7 0.3029875
# NPCTrainers                  1     0.00     39711     4009.7 0.9586925
# NPCVendors                   1     5.15     39710     4004.6 0.0232212 *
# NPCs                         1     0.00     39709     4004.6 0.9864105
# PlantsFoliage                1    18.04     39708     3986.5 2.167e-05 ***
# Weapons                      1     0.66     39707     3985.9 0.4176004
# AnimationModified            1   103.68     39706     3882.2 < 2.2e-16 ***
# AnimationNew                 1    11.25     39705     3870.9 0.0007944 ***
# AudioSoundFX                 1     7.09     39704     3863.8 0.0077438 **
# AudioVoices                  1     6.14     39703     3857.7 0.0132272 *
# Birthsigns                   1     4.70     39702     3853.0 0.0301394 *
# Bodymodels                   1     0.06     39701     3852.9 0.8020199
# Classescomponent             1     1.95     39700     3851.0 0.1625492
# EnvironmentOther             1    69.99     39699     3781.0 < 2.2e-16 ***
# EnvironmentSky               1     0.77     39698     3780.2 0.3794944
# EnvironmentWater             1     0.42     39697     3779.8 0.5174970
# EnvironmentWeather           1    10.04     39696     3769.8 0.0015320 **
# Facemodels                   1    22.60     39695     3747.2 1.993e-06 ***
# GuildsFactions               1     1.69     39694     3745.5 0.1933596
# Hair                         1     4.19     39693     3741.3 0.0406555 *
# LeveledLists                 1    16.42     39692     3724.9 5.064e-05 ***
# Lighting                     1     0.12     39691     3724.7 0.7299456
# NewLands                     1     2.68     39690     3722.1 0.1019070
# Newmodels                    1    19.02     39689     3703.0 1.292e-05 ***
# Newtextures                  1    71.13     39688     3631.9 < 2.2e-16 ***
# Quests                       1     4.94     39687     3627.0 0.0262448 *
# RacesModified                1     0.16     39686     3626.8 0.6905308
# ScriptedEvents               1    12.48     39685     3614.3 0.0004106 ***
# Video                        1     0.16     39684     3614.2 0.6930283
# Chargen                      1    46.90     39683     3567.3 7.462e-12 ***
# CompanionFriendly            1     1.14     39682     3566.1 0.2853123
# Companions                   1     5.00     39681     3561.1 0.0253107 *
# Compilation                  1     1.14     39680     3560.0 0.2855264
# ENBPreset                    1    17.95     39679     3542.0 2.262e-05 ***
# Forfemalecharacters          1     0.08     39678     3542.0 0.7733985
# Formalecharacters            1     3.48     39677     3538.5 0.0620497 .
# GameplayEffectsChanges       1    73.28     39676     3465.2 < 2.2e-16 ***
# Official                     1    13.35     39675     3451.8 0.0002589 ***
# PerformanceOptimization      1    56.02     39674     3395.8 7.192e-14 ***
# Poses                        1     1.29     39673     3394.5 0.2552608
# Relatedtohorses              1     0.03     39672     3394.5 0.8653624
# RelatedtoMoviesTVOtherGames  1     6.49     39671     3388.0 0.0108596 *
# Relatedtovampires            1     0.18     39670     3387.8 0.6703472
# Replacer                     1    53.48     39669     3334.3 2.610e-13 ***
# Solstheim                    1     0.31     39668     3334.0 0.5803336
# none                         1    34.10     39667     3299.9 5.248e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
anova(modl2, test="Chi");
# Out:
# Analysis of Deviance Table
#
# Model: binomial, link: logit
#
# Response: Pop10
#
# Terms added sequentially (first to last)
#
#
#                             Df Deviance Resid. Df Resid. Dev  Pr(>Chi)
# NULL                                        39739      25838
# Anime                        1   186.76     39738      25651 < 2.2e-16 ***
# LoreFriendly                 1   602.65     39737      25048 < 2.2e-16 ***
# NotLoreFriendly              1    81.87     39736      24966 < 2.2e-16 ***
# NotSafeForWork               1    83.54     39735      24883 < 2.2e-16 ***
# Nudity                       1    15.36     39734      24867 8.901e-05 ***
# SexySkimpy                   1   217.49     39733      24650 < 2.2e-16 ***
# Unrealistic                  1    69.61     39732      24580 < 2.2e-16 ***
# ArmorShields                 1    10.87     39731      24569 0.0009788 ***
# Books                        1     1.19     39730      24568 0.2754726
# Clothing                     1    44.60     39729      24524 2.416e-11 ***
# ClothingFemale               1    38.18     39728      24486 6.454e-10 ***
# ClothingMale                 1     9.15     39727      24476 0.0024861 **
# Creatures                    1    20.27     39726      24456 6.735e-06 ***
# CreaturesRideable            1    10.19     39725      24446 0.0014104 **
# ItemsApparatus               1     1.25     39724      24445 0.2631251
# ItemsClutter                 1     4.01     39723      24441 0.0452488 *
# ItemsFurniture               1     0.26     39722      24440 0.6119857
# ItemsIngredients             1     0.02     39721      24440 0.8912342
# ItemsLeveled                 1     1.77     39720      24439 0.1834662
# LocationsBuildings           1     1.56     39719      24437 0.2113032
# LocationsCaverns             1     1.41     39718      24436 0.2352015
# LocationsDungeons            1     3.26     39717      24432 0.0711074 .
# LocationsPlayerOwned         1    15.81     39716      24416 7.020e-05 ***
# LocationsWorldMap            1     8.89     39715      24408 0.0028724 **
# MagicEnchantments            1     2.25     39714      24405 0.1338058
# MagicPotions                 1     3.04     39713      24402 0.0811590 .
# MagicSpells                  1     1.31     39712      24401 0.2520589
# NPCTrainers                  1     3.57     39711      24398 0.0588693 .
# NPCVendors                   1    21.36     39710      24376 3.800e-06 ***
# NPCs                         1     1.25     39709      24375 0.2641451
# PlantsFoliage                1    21.76     39708      24353 3.088e-06 ***
# Weapons                      1    11.94     39707      24341 0.0005483 ***
# AnimationModified            1   224.25     39706      24117 < 2.2e-16 ***
# AnimationNew                 1    48.57     39705      24068 3.181e-12 ***
# AudioSoundFX                 1     9.38     39704      24059 0.0021925 **
# AudioVoices                  1     3.48     39703      24056 0.0622271 .
# Birthsigns                   1    14.61     39702      24041 0.0001320 ***
# Bodymodels                   1     0.10     39701      24041 0.7559549
# Classescomponent             1     2.20     39700      24039 0.1375885
# EnvironmentOther             1   127.56     39699      23911 < 2.2e-16 ***
# EnvironmentSky               1     2.61     39698      23908 0.1062487
# EnvironmentWater             1     1.91     39697      23906 0.1671353
# EnvironmentWeather           1    15.30     39696      23891 9.181e-05 ***
# Facemodels                   1     2.76     39695      23888 0.0965030 .
# GuildsFactions               1     0.13     39694      23888 0.7235405
# Hair                         1    11.11     39693      23877 0.0008572 ***
# LeveledLists                 1    21.74     39692      23855 3.121e-06 ***
# Lighting                     1     2.34     39691      23853 0.1264056
# NewLands                     1     0.80     39690      23852 0.3718974
# Newmodels                    1   194.35     39689      23658 < 2.2e-16 ***
# Newtextures                  1   268.33     39688      23390 < 2.2e-16 ***
# Quests                       1    28.44     39687      23361 9.656e-08 ***
# RacesModified                1     0.27     39686      23361 0.6024035
# ScriptedEvents               1    71.16     39685      23290 < 2.2e-16 ***
# Video                        1     5.56     39684      23284 0.0184183 *
# Chargen                      1    29.19     39683      23255 6.552e-08 ***
# CompanionFriendly            1     0.06     39682      23255 0.8001691
# Companions                   1     0.49     39681      23254 0.4834281
# Compilation                  1     6.11     39680      23248 0.0134679 *
# ENBPreset                    1    15.78     39679      23233 7.121e-05 ***
# Forfemalecharacters          1     0.16     39678      23232 0.6888143
# Formalecharacters            1    12.13     39677      23220 0.0004974 ***
# GameplayEffectsChanges       1   165.39     39676      23055 < 2.2e-16 ***
# Official                     1    51.82     39675      23003 6.095e-13 ***
# PerformanceOptimization      1    75.76     39674      22927 < 2.2e-16 ***
# Poses                        1     2.00     39673      22925 0.1568708
# Relatedtohorses              1     2.11     39672      22923 0.1466572
# RelatedtoMoviesTVOtherGames  1    22.26     39671      22901 2.380e-06 ***
# Relatedtovampires            1     3.80     39670      22897 0.0513026 .
# Replacer                     1    50.97     39669      22846 9.375e-13 ***
# Solstheim                    1     1.08     39668      22845 0.2979383
# none                         1   127.17     39667      22718 < 2.2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
